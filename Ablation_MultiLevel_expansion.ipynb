# %%
from src.Planners.H_MCTS_HW import H_MCTS_HW
from src.Planners.H_MCTS_wo_MultiL_Expand.H_MCTS import H_MCTS

import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
l1_rows = 8
l1_cols = 8
l1_width = 2
l1_height = 2
# H_level = 2
num_barrier = 15
random_seed= 25

explorationConstant1 = 1 / math.sqrt(2)
explorationConstant2 = 1 / (math.sqrt(2))
grid_setting = (l1_rows, l1_cols, l1_width, l1_height)

iter_Limit = 10000
H_level = 2

# %%
r = 0
dead_list = [3, 19, 22, 29, 37, 43, 50, 54, 59, 62, 79, 110]  # unfeasible set

num_set = 5

success_data = dict()
iteration_data = dict()
traj_data = dict()
level2_dict = dict()
level1_dict = dict()

modules = ['H_woE', 'H']

for module in modules:
    success_data[module] = []
    iteration_data[module] = []
    traj_data[module] = []
    level2_dict[module] = []
    level1_dict[module] = []
Success_H = 0
Success_Plain = 0

H_level = 2

for i in range(1):
    for random_seed in range(0, 112):
    # for random_seed in range(6, 7):

        if random_seed in dead_list:
            continue
        else:
            print(f'random seed is {random_seed}')
            H_mcts = H_MCTS_HW(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant2, num_barrier=num_barrier, random_seed=random_seed)
            H_mcts_woE = H_MCTS(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant1, num_barrier=num_barrier, random_seed=random_seed)
            
            H_mcts.env.plot_grid(1)
            
            H_traj, H_success, H_iter = H_mcts.search()
            H_woE_traj, H_woE_success, H_woE_iter = H_mcts_woE.search()
            
            level2_dict['H'].append(H_mcts.level2)
            level2_dict['H_woE'].append(H_mcts_woE.level1)
            level1_dict['H'].append(H_mcts.level1)
            level1_dict['H_woE'].append(H_mcts_woE.level1)
            
            print(f'H: {H_iter}, H_woE: {H_woE_iter}')
            
            success_data['H'].append(H_success)
            success_data['H_woE'].append(H_woE_success)

            iteration_data['H'].append(H_iter)
            iteration_data['H_woE'].append(H_woE_iter)
            
            if H_traj is not None:
                traj_data['H'].append(len(H_traj))
            else:
                traj_data['H'].append(None)
                
            if H_woE_traj is not None:
                traj_data['H_woE'].append(len(H_woE_traj))
            else:
                traj_data['H_woE'].append(None)
# Out:
# random seed is 0
# H: 87, H_woE: 90
# random seed is 1
# H: 493, H_woE: 3397
# random seed is 2
# H: 739, H_woE: 203
# random seed is 4
# H: 144, H_woE: 189
# random seed is 5
# H: 414, H_woE: 206
# random seed is 6
# H: 87, H_woE: 83
# random seed is 7
# H: 31, H_woE: 20
# random seed is 8
# H: 53, H_woE: 56
# random seed is 9
# H: 921, H_woE: 1236
# random seed is 10
# H: 38, H_woE: 31
# random seed is 11
# H: 32, H_woE: 25
# random seed is 12
# H: 18, H_woE: 17
# random seed is 13
# H: 29, H_woE: 27
# random seed is 14
# H: 789, H_woE: 772
# random seed is 15
# H: 10, H_woE: 8
# random seed is 16
# H: 258, H_woE: 383
# random seed is 17
# H: 115, H_woE: 34
# random seed is 18
# H: 35, H_woE: 25
# random seed is 20
# H: 46, H_woE: 97
# random seed is 21
# H: 142, H_woE: 327
# random seed is 23
# H: 112, H_woE: 124
# random seed is 24
# H: 75, H_woE: 71
# random seed is 25
# H: 51, H_woE: 53
# random seed is 26
# H: 199, H_woE: 103
# random seed is 27
# H: 19, H_woE: 22
# random seed is 28
# H: 54, H_woE: 44
# random seed is 30
# H: 1146, H_woE: 519
# random seed is 31
# H: 58, H_woE: 72
# random seed is 32
# H: 61, H_woE: 44
# random seed is 33
# H: 54, H_woE: 46
# random seed is 34
# H: 80, H_woE: 75
# random seed is 35
# H: 81, H_woE: 87
# random seed is 36
# H: 10, H_woE: 15
# random seed is 38
# H: 20, H_woE: 22
# random seed is 39
# H: 55, H_woE: 44
# random seed is 40
# H: 116, H_woE: 616
# random seed is 41
# H: 46, H_woE: 32
# random seed is 42
# H: 24, H_woE: 23
# random seed is 44
# H: 193, H_woE: 178
# random seed is 45
# H: 158, H_woE: 38
# random seed is 46
# H: 69, H_woE: 50
# random seed is 47
# H: 15, H_woE: 7
# random seed is 48
# H: 312, H_woE: 154
# random seed is 49
# H: 575, H_woE: 582
# random seed is 51
# H: 555, H_woE: 613
# random seed is 52
# H: 19, H_woE: 18
# random seed is 53
# H: 230, H_woE: 213
# random seed is 55
# H: 12, H_woE: 11
# random seed is 56
# H: 15, H_woE: 13
# random seed is 57
# H: 8, H_woE: 7
# random seed is 58
# H: 534, H_woE: 197
# random seed is 60
# H: 44, H_woE: 31
# random seed is 61
# H: 37, H_woE: 29
# random seed is 63
# H: 209, H_woE: 203
# random seed is 64
# H: 119, H_woE: 85
# random seed is 65
# H: 54, H_woE: 44
# random seed is 66
# H: 56, H_woE: 44
# random seed is 67
# H: 91, H_woE: 77
# random seed is 68
# H: 20, H_woE: 25
# random seed is 69
# H: 46, H_woE: 67
# random seed is 70
# H: 167, H_woE: 122
# random seed is 71
# H: 85, H_woE: 94
# random seed is 72
# H: 617, H_woE: 572
# random seed is 73
# H: 52, H_woE: 122
# random seed is 74
# H: 22, H_woE: 20
# random seed is 75
# H: 60, H_woE: 62
# random seed is 76
# H: 20, H_woE: 28
# random seed is 77
# H: 30, H_woE: 26
# random seed is 78
# H: 112, H_woE: 67
# random seed is 80
# H: 1003, H_woE: 568
# random seed is 81
# H: 5909, H_woE: 10000
# random seed is 82
# H: 441, H_woE: 190
# random seed is 83
# H: 444, H_woE: 1200
# random seed is 84
# H: 27, H_woE: 30
# random seed is 85
# H: 77, H_woE: 98
# random seed is 86
# H: 28, H_woE: 29
# random seed is 87
# H: 111, H_woE: 121
# random seed is 88
# H: 36, H_woE: 35
# random seed is 89
# H: 159, H_woE: 106
# random seed is 90
# H: 266, H_woE: 234
# random seed is 91
# H: 23, H_woE: 16
# random seed is 92
# H: 642, H_woE: 1265
# random seed is 93
# H: 403, H_woE: 132
# random seed is 94
# H: 12, H_woE: 11
# random seed is 95
# H: 1303, H_woE: 1936
# random seed is 96
# H: 190, H_woE: 124
# random seed is 97
# H: 2691, H_woE: 1058
# random seed is 98
# H: 204, H_woE: 188
# random seed is 99
# H: 58, H_woE: 26
# random seed is 100
# H: 703, H_woE: 10000
# random seed is 101
# H: 113, H_woE: 91
# random seed is 102
# H: 11, H_woE: 8
# random seed is 103
# H: 12, H_woE: 12
# random seed is 104
# H: 35, H_woE: 38
# random seed is 105
# H: 32, H_woE: 46
# random seed is 106
# H: 27, H_woE: 30
# random seed is 107
# H: 298, H_woE: 86
# random seed is 108
# H: 88, H_woE: 64
# random seed is 109
# H: 18, H_woE: 12
# random seed is 111
# H: 50, H_woE: 43

# %%
df_success = pd.DataFrame(success_data)

df_success_rate = pd.DataFrame({
    'without Extendable': [df_success['H_woE'].mean()],
    'with Extendable': [df_success['H'].mean()]
}, index=['H-MCTS'])

print(df_success_rate)
# Out:
#         without Extendable  with Extendable
# H-MCTS                0.98              1.0

# %%
df_success = pd.DataFrame(level2_dict)

df_success_rate = pd.DataFrame({
    'without Extendable': [df_success['H_woE'].mean()],
    'with Extendable': [df_success['H'].mean()]
}, index=['H-MCTS'])

print(df_success_rate)
# Out:
#         without Extendable  with Extendable
# H-MCTS              359.38           117.59

# %%
df_success = pd.DataFrame(level1_dict)

df_success_rate = pd.DataFrame({
    'without Extendable': [df_success['H_woE'].mean()],
    'with Extendable': [df_success['H'].mean()]
}, index=['H-MCTS'])

print(df_success_rate)
# Out:
#         without Extendable  with Extendable
# H-MCTS              359.38           149.33

# %%
H = 0
woE = 0

for H_len, woe_len in zip(traj_data['H'], traj_data['H_woE']):
    if H_len is None and woe_len is None:
        pass
    elif H_len is None and woe_len is not None:
        woE += 1
    elif woe_len is None and H_len is not None:
        H += 1
    else:
        if H_len > woe_len:
            woE += 1
        elif H_len == woe_len:
            pass
        else:
            H+=1
print(H, woE)
# Out:
# 10 15

# %%
import numpy as np
import matplotlib.pyplot as plt

# Filter the iteration_data based on success
filtered_iteration_data = {module: [] for module in modules}

for i in range(len(success_data['H_woE'])):
    if all([success_data[module][i] for module in modules]):
        for module in modules:
            filtered_iteration_data[module].append(iteration_data[module][i])

# Calculate mean and standard deviation
mean_data = {module: np.mean(filtered_iteration_data[module]) for module in modules}
std_data = {module: np.std(filtered_iteration_data[module]) for module in modules}

# Plotting the mean and standard deviation
labels = list(mean_data.keys())
mean_vals = list(mean_data.values())
std_vals = list(std_data.values())

x = np.arange(len(labels))  # the label locations

colors = ['blue', 'green', 'red', 'purple']  # Define colors for each module

fig, ax = plt.subplots()
for i in range(len(labels)):
    # Only positive error bars
    ax.bar(x[i], mean_vals[i], yerr=[[0], [std_vals[i]]], color=colors[i], capsize=10)

ax.set_yscale('log') # Change y-axis to log scale

# Remaining part of the code
ax.set_ylabel('Iterations until find the path')
ax.set_title('Extendable ablation')
ax.set_xticks(x)
ax.set_xticklabels(labels)

fig.tight_layout()

plt.show()
