# %%
from src.Planners.H_MCTS_HW import H_MCTS_HW
from src.Planners.H_MCTS_wo_Extendable.H_MCTS import H_MCTS

import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
l1_rows = 8
l1_cols = 8
l1_width = 2
l1_height = 2
# H_level = 2
num_barrier = 15
random_seed= 25

explorationConstant = 1 / math.sqrt(2)
grid_setting = (l1_rows, l1_cols, l1_width, l1_height)

iter_Limit = 10000
H_level = 2

# %%
r = 0
dead_list = [3, 19, 22, 29, 37, 43, 50, 54, 59, 62, 79, 110]  # unfeasible set

num_set = 5

success_data = dict()
iteration_data = dict()

modules = ['H_woE', 'H']

for module in modules:
    success_data[module] = []
    iteration_data[module] = []

Success_H = 0
Success_Plain = 0

H_level = 2
Plain_level = 1
for i in range(num_set):
    for random_seed in range(0, 112):
    # for random_seed in range(6, 7):

        if random_seed in dead_list:
            continue
        else:
            print(f'random seed is {random_seed}')
            H_mcts = H_MCTS_HW3(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
            H_mcts_woE = H_MCTS(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
            
            H_traj, H_success, H_iter = H_mcts.search()
            H_woE_traj, H_woE_success, H_woE_iter = H_mcts_woE.search()
            
            print(f'H: {H_iter}, H_woE: {H_woE_iter}')
            
            success_data['H'].append(H_success)
            success_data['H_woE'].append(H_woE_success)

            iteration_data['H'].append(H_iter)
            iteration_data['H_woE'].append(H_woE_iter)
# Out:
# random seed is 0
# subgoal Increased, [(2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 63, H_woE: 93
# random seed is 1
# subgoal Increased, [(2, 1, 3), (2, 1, 2), (2, 2, 2), (2, 2, 1), (2, 3, 1), (2, 3, 0)]
# H: 352, H_woE: 838
# random seed is 2
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 2, 2), (2, 2, 3), (2, 1, 3)]
# H: 165, H_woE: 275
# random seed is 4
# subgoal Increased, [(2, 2, 2), (2, 3, 2), (2, 3, 3)]
# H: 63, H_woE: 121
# random seed is 5
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2), (2, 0, 2), (2, 0, 3)]
# H: 222, H_woE: 321
# random seed is 6
# subgoal Increased, [(2, 1, 2), (2, 0, 2)]
# H: 98, H_woE: 80
# random seed is 7
# subgoal Increased, [(2, 1, 1), (2, 2, 1)]
# H: 28, H_woE: 13
# random seed is 8
# subgoal Increased, [(2, 3, 0), (2, 2, 0), (2, 1, 0)]
# H: 996, H_woE: 37
# random seed is 9
# subgoal Increased, [(2, 1, 3), (2, 1, 2), (2, 1, 1), (2, 1, 0)]
# H: 715, H_woE: 1474
# random seed is 10
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 34, H_woE: 23
# random seed is 11
# subgoal Increased, [(2, 2, 1), (2, 3, 1)]
# H: 34, H_woE: 29
# random seed is 12
# subgoal Increased, [(2, 0, 3)]
# H: 21, H_woE: 17
# random seed is 13
# subgoal Increased, [(2, 1, 0), (2, 2, 0)]
# H: 24, H_woE: 29
# random seed is 14
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 198, H_woE: 265
# random seed is 15
# subgoal Increased, [(2, 1, 1)]
# H: 14, H_woE: 10
# random seed is 16
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 0, 1), (2, 0, 2)]
# H: 634, H_woE: 107
# random seed is 17
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 2, 1)]
# H: 75, H_woE: 51
# random seed is 18
# subgoal Increased, [(2, 2, 1), (2, 2, 0)]
# H: 34, H_woE: 36
# random seed is 20
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 0, 1)]
# H: 47, H_woE: 33
# random seed is 21
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 1, 1), (2, 1, 2)]
# H: 81, H_woE: 114
# random seed is 23
# subgoal Increased, [(2, 1, 0), (2, 0, 0), (2, 0, 1), (2, 0, 2)]
# H: 102, H_woE: 86
# random seed is 24
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 55, H_woE: 79
# random seed is 25
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 2, 1)]
# H: 54, H_woE: 65
# random seed is 26
# subgoal Increased, [(2, 2, 1), (2, 1, 1), (2, 0, 1), (2, 0, 2)]
# H: 119, H_woE: 108
# random seed is 27
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 23, H_woE: 24
# random seed is 28
# subgoal Increased, [(2, 2, 1), (2, 3, 1), (2, 3, 0)]
# H: 63, H_woE: 44
# random seed is 30
# subgoal Increased, [(2, 0, 2), (2, 0, 3), (2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 217, H_woE: 239
# random seed is 31
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3)]
# H: 61, H_woE: 56
# random seed is 32
# subgoal Increased, [(2, 2, 2), (2, 1, 2), (2, 0, 2)]
# H: 47, H_woE: 160
# random seed is 33
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 47, H_woE: 45
# random seed is 34
# subgoal Increased, [(2, 2, 2), (2, 1, 2)]
# H: 57, H_woE: 72
# random seed is 35
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 2, 2), (2, 2, 3)]
# H: 66, H_woE: 106
# random seed is 36
# subgoal Increased, [(2, 1, 0)]
# H: 11, H_woE: 11
# random seed is 38
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 23, H_woE: 27
# random seed is 39
# subgoal Increased, [(2, 3, 3), (2, 2, 3)]
# H: 58, H_woE: 18
# random seed is 40
# subgoal Increased, [(2, 3, 2), (2, 3, 3), (2, 2, 3), (2, 1, 3)]
# H: 86, H_woE: 123
# random seed is 41
# subgoal Increased, [(2, 2, 2)]
# H: 32, H_woE: 56
# random seed is 42
# subgoal Increased, [(2, 0, 0), (2, 0, 1)]
# H: 18, H_woE: 18
# random seed is 44
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 2, 2), (2, 2, 3)]
# H: 111, H_woE: 167
# random seed is 45
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 35, H_woE: 38
# random seed is 46
# subgoal Increased, [(2, 0, 1), (2, 0, 2), (2, 1, 2), (2, 2, 2)]
# H: 65, H_woE: 61
# random seed is 47
# subgoal Increased, [(2, 2, 1)]
# H: 10, H_woE: 11
# random seed is 48
# subgoal Increased, [(2, 2, 2), (2, 1, 2), (2, 1, 1)]
# H: 245, H_woE: 108
# random seed is 49
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 3, 0), (2, 2, 0)]
# H: 55, H_woE: 82
# random seed is 51
# subgoal Increased, [(2, 2, 2), (2, 2, 1), (2, 2, 0)]
# H: 161, H_woE: 591
# random seed is 52
# subgoal Increased, [(2, 3, 0), (2, 2, 0)]
# H: 18, H_woE: 22
# random seed is 53
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 3, 1)]
# H: 108, H_woE: 235
# random seed is 55
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 11, H_woE: 10
# random seed is 56
# subgoal Increased, [(2, 2, 0), (2, 2, 1)]
# H: 14, H_woE: 15
# random seed is 57
# subgoal Increased, [(2, 1, 0)]
# H: 7, H_woE: 6
# random seed is 58
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 1, 2), (2, 0, 2), (2, 0, 1)]
# H: 137, H_woE: 168
# random seed is 60
# subgoal Increased, [(2, 3, 1), (2, 3, 2)]
# H: 34, H_woE: 35
# random seed is 61
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 40, H_woE: 37
# random seed is 63
# subgoal Increased, [(2, 1, 2), (2, 1, 1), (2, 2, 1), (2, 3, 1)]
# H: 164, H_woE: 88
# random seed is 64
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# subgoal Increased, [(2, 2, 3), (2, 2, 2)]
# subgoal Increased, [(2, 0, 3), (2, 1, 3), (2, 1, 2), (2, 2, 2)]
# H: 45, H_woE: 89
# random seed is 65
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 40, H_woE: 42
# random seed is 66
# subgoal Increased, [(2, 0, 0), (2, 1, 0), (2, 2, 0)]
# H: 29, H_woE: 30
# random seed is 67
# subgoal Increased, [(2, 1, 2), (2, 1, 3), (2, 2, 3)]
# H: 62, H_woE: 94
# random seed is 68
# subgoal Increased, [(2, 2, 3)]
# H: 18, H_woE: 25
# random seed is 69
# subgoal Increased, [(2, 3, 1)]
# H: 59, H_woE: 50
# random seed is 70
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2), (2, 1, 1)]
# H: 99, H_woE: 71
# random seed is 71
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 2, 1), (2, 1, 1)]
# H: 71, H_woE: 144
# random seed is 72
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 280, H_woE: 476
# random seed is 73
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 39, H_woE: 45
# random seed is 74
# subgoal Increased, [(2, 2, 0), (2, 3, 0)]
# H: 24, H_woE: 17
# random seed is 75
# subgoal Increased, [(2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 84, H_woE: 49
# random seed is 76
# subgoal Increased, [(2, 3, 3), (2, 2, 3)]
# H: 18, H_woE: 19
# random seed is 77
# subgoal Increased, [(2, 2, 0), (2, 3, 0)]
# H: 23, H_woE: 21
# random seed is 78
# subgoal Increased, [(2, 2, 1)]
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 2, 1)]
# H: 245, H_woE: 89
# random seed is 80
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, 2, 3), (2, 3, 3)]
# H: 597, H_woE: 340
# random seed is 81
# subgoal Increased, [(2, 0, 2)]
# H: 578, H_woE: 10000
# random seed is 82
# subgoal Increased, [(2, 2, 0), (2, 3, 0), (2, 3, 1), (2, 3, 2)]
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 2, 2), (2, 3, 2)]
# H: 501, H_woE: 156
# random seed is 83
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 1, 1), (2, 1, 2), (2, 0, 2), (2, 0, 3)]
# H: 254, H_woE: 740
# random seed is 84
# subgoal Increased, [(2, 2, 2), (2, 2, 1)]
# H: 25, H_woE: 26
# random seed is 85
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 75, H_woE: 85
# random seed is 86
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 19, H_woE: 28
# random seed is 87
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 68, H_woE: 89
# random seed is 88
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1)]
# H: 39, H_woE: 45
# random seed is 89
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 2, 2), (2, 1, 2)]
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 1, 1), (2, 1, 2)]
# H: 97, H_woE: 139
# random seed is 90
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3), (2, 3, 2), (2, 3, 1)]
# H: 150, H_woE: 270
# random seed is 91
# subgoal Increased, [(2, 3, 1)]
# H: 21, H_woE: 17
# random seed is 92
# subgoal Increased, [(2, 1, 3), (2, 1, 2), (2, 1, 1), (2, 2, 1), (2, 2, 0), (2, 3, 0)]
# H: 548, H_woE: 1112
# random seed is 93
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 1, 1), (2, 0, 1)]
# H: 105, H_woE: 179
# random seed is 94
# subgoal Increased, [(2, 2, 1)]
# H: 9, H_woE: 11
# random seed is 95
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 1, 2), (2, 0, 2), (2, 0, 1), (2, 0, 0)]
# H: 1449, H_woE: 1280
# random seed is 96
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# H: 70, H_woE: 96
# random seed is 97
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 3, 0), (2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 806, H_woE: 393
# random seed is 98
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3)]
# H: 111, H_woE: 216
# random seed is 99
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2)]
# H: 46, H_woE: 55
# random seed is 100
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1), (2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 320, H_woE: 10000
# random seed is 101
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 92, H_woE: 117
# random seed is 102
# subgoal Increased, [(2, 3, 2)]
# H: 8, H_woE: 10
# random seed is 103
# subgoal Increased, [(2, 1, 3)]
# H: 13, H_woE: 15
# random seed is 104
# subgoal Increased, [(2, 3, 2), (2, 3, 3)]
# H: 30, H_woE: 33
# random seed is 105
# subgoal Increased, [(2, 2, 0)]
# H: 44, H_woE: 22
# random seed is 106
# subgoal Increased, [(2, 1, 3)]
# H: 21, H_woE: 21
# random seed is 107
# subgoal Increased, [(2, 1, 2), (2, 0, 2), (2, 0, 3)]
# H: 106, H_woE: 206
# random seed is 108
# subgoal Increased, [(2, 2, 2), (2, 2, 3), (2, 3, 3)]
# H: 78, H_woE: 63
# random seed is 109
# subgoal Increased, [(2, 2, 2), (2, 2, 1)]
# H: 17, H_woE: 14
# random seed is 111
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 54, H_woE: 41
# random seed is 0
# subgoal Increased, [(2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 59, H_woE: 92
# random seed is 1
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 1, 1), (2, 2, 1), (2, 3, 1), (2, 3, 0)]
# H: 338, H_woE: 2162
# random seed is 2
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3), (2, 2, 3), (2, 1, 3)]
# H: 625, H_woE: 224
# random seed is 4
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 83, H_woE: 38
# random seed is 5
# subgoal Increased, [(2, 2, 1), (2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 0, 3)]
# H: 464, H_woE: 349
# random seed is 6
# subgoal Increased, [(2, 1, 2), (2, 0, 2)]
# H: 98, H_woE: 84
# random seed is 7
# subgoal Increased, [(2, 2, 0), (2, 2, 1)]
# H: 24, H_woE: 19
# random seed is 8
# subgoal Increased, [(2, 3, 0), (2, 2, 0), (2, 1, 0)]
# H: 35, H_woE: 57
# random seed is 9
# subgoal Increased, [(2, 1, 3), (2, 1, 2), (2, 1, 1), (2, 1, 0)]
# H: 200, H_woE: 1512
# random seed is 10
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 40, H_woE: 39
# random seed is 11
# subgoal Increased, [(2, 2, 1), (2, 3, 1)]
# H: 26, H_woE: 24
# random seed is 12
# subgoal Increased, [(2, 0, 3)]
# H: 16, H_woE: 19
# random seed is 13
# subgoal Increased, [(2, 1, 0), (2, 2, 0)]
# H: 25, H_woE: 29
# random seed is 14
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, 2, 3), (2, 3, 3)]
# H: 559, H_woE: 450
# random seed is 15
# subgoal Increased, [(2, 1, 1)]
# H: 16, H_woE: 7
# random seed is 16
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 0, 1), (2, 0, 2)]
# H: 10000, H_woE: 118
# random seed is 17
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 2, 1)]
# H: 73, H_woE: 66
# random seed is 18
# subgoal Increased, [(2, 2, 1), (2, 2, 0)]
# H: 48, H_woE: 29
# random seed is 20
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 0, 1)]
# H: 40, H_woE: 37
# random seed is 21
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 2, 2), (2, 1, 2)]
# H: 76, H_woE: 297
# random seed is 23
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 0, 1), (2, 0, 2)]
# H: 99, H_woE: 96
# random seed is 24
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 60, H_woE: 64
# random seed is 25
# subgoal Increased, [(2, 1, 2), (2, 1, 1), (2, 2, 1)]
# H: 42, H_woE: 46
# random seed is 26
# subgoal Increased, [(2, 2, 1), (2, 2, 2), (2, 1, 2), (2, 0, 2)]
# H: 122, H_woE: 103
# random seed is 27
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 17, H_woE: 25
# random seed is 28
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 3, 0)]
# H: 47, H_woE: 57
# random seed is 30
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, 3, 2), (2, 3, 3)]
# H: 247, H_woE: 332
# random seed is 31
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3)]
# H: 74, H_woE: 69
# random seed is 32
# subgoal Increased, [(2, 1, 3), (2, 0, 3), (2, 0, 2)]
# H: 52, H_woE: 49
# random seed is 33
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 49, H_woE: 46
# random seed is 34
# subgoal Increased, [(2, 2, 2), (2, 1, 2)]
# H: 55, H_woE: 69
# random seed is 35
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3), (2, 2, 3)]
# H: 90, H_woE: 87
# random seed is 36
# subgoal Increased, [(2, 1, 0)]
# H: 13, H_woE: 19
# random seed is 38
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 23, H_woE: 25
# random seed is 39
# subgoal Increased, [(2, 3, 3), (2, 2, 3)]
# H: 23, H_woE: 29
# random seed is 40
# subgoal Increased, [(2, 3, 2), (2, 3, 3), (2, 2, 3), (2, 1, 3)]
# H: 85, H_woE: 149
# random seed is 41
# subgoal Increased, [(2, 2, 2)]
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 2, 2)]
# H: 51, H_woE: 47
# random seed is 42
# subgoal Increased, [(2, 0, 0), (2, 0, 1)]
# H: 18, H_woE: 16
# random seed is 44
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3)]
# H: 98, H_woE: 104
# random seed is 45
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 37, H_woE: 63
# random seed is 46
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 2, 1), (2, 2, 2)]
# H: 74, H_woE: 65
# random seed is 47
# subgoal Increased, [(2, 2, 1)]
# H: 14, H_woE: 11
# random seed is 48
# subgoal Increased, [(2, 1, 3), (2, 1, 2), (2, 1, 1)]
# subgoal Increased, [(2, 2, 2), (2, 1, 2), (2, 1, 1)]
# H: 88, H_woE: 201
# random seed is 49
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 3, 0), (2, 2, 0)]
# H: 63, H_woE: 77
# random seed is 51
# subgoal Increased, [(2, 2, 2), (2, 2, 1), (2, 2, 0)]
# H: 159, H_woE: 658
# random seed is 52
# subgoal Increased, [(2, 3, 0), (2, 2, 0)]
# H: 20, H_woE: 20
# random seed is 53
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 3, 1)]
# H: 107, H_woE: 217
# random seed is 55
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 13, H_woE: 10
# random seed is 56
# subgoal Increased, [(2, 2, 0), (2, 2, 1)]
# H: 14, H_woE: 10
# random seed is 57
# subgoal Increased, [(2, 1, 0)]
# H: 7, H_woE: 7
# random seed is 58
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 1, 2), (2, 1, 1), (2, 0, 1)]
# H: 178, H_woE: 224
# random seed is 60
# subgoal Increased, [(2, 3, 1), (2, 3, 2)]
# H: 40, H_woE: 39
# random seed is 61
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 52, H_woE: 37
# random seed is 63
# subgoal Increased, [(2, 0, 1), (2, 1, 1), (2, 2, 1), (2, 3, 1)]
# H: 158, H_woE: 97
# random seed is 64
# subgoal Increased, [(2, 2, 3), (2, 2, 2)]
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# subgoal Increased, [(2, 0, 3), (2, 0, 2), (2, 1, 2), (2, 2, 2)]
# H: 45, H_woE: 80
# random seed is 65
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 39, H_woE: 42
# random seed is 66
# subgoal Increased, [(2, 0, 0), (2, 1, 0), (2, 2, 0)]
# H: 26, H_woE: 30
# random seed is 67
# subgoal Increased, [(2, 1, 2), (2, 2, 2), (2, 2, 3)]
# H: 342, H_woE: 72
# random seed is 68
# subgoal Increased, [(2, 2, 3)]
# H: 18, H_woE: 19
# random seed is 69
# subgoal Increased, [(2, 3, 1)]
# H: 46, H_woE: 53
# random seed is 70
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 1, 2), (2, 1, 1)]
# H: 80, H_woE: 102
# random seed is 71
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1), (2, 1, 1)]
# H: 80, H_woE: 154
# random seed is 72
# subgoal Increased, [(2, 0, 1), (2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 369, H_woE: 461
# random seed is 73
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 64, H_woE: 44
# random seed is 74
# subgoal Increased, [(2, 3, 1), (2, 3, 0)]
# H: 18, H_woE: 19
# random seed is 75
# subgoal Increased, [(2, 1, 2), (2, 0, 2), (2, 0, 3)]
# H: 34, H_woE: 38
# random seed is 76
# subgoal Increased, [(2, 2, 2), (2, 2, 3)]
# H: 19, H_woE: 16
# random seed is 77
# subgoal Increased, [(2, 2, 0), (2, 3, 0)]
# H: 28, H_woE: 20
# random seed is 78
# subgoal Increased, [(2, 2, 1)]
# subgoal Increased, [(2, 1, 2), (2, 2, 2), (2, 2, 1)]
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 2, 1)]
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1)]
# H: 84, H_woE: 101
# random seed is 80
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 187, H_woE: 305
# random seed is 81
# subgoal Increased, [(2, 0, 2)]
# subgoal Increased, [(2, 1, 3), (2, 0, 3), (2, 0, 2)]
# subgoal Increased, [(2, 1, 1), (2, 0, 1), (2, 0, 2)]
# subgoal Increased, [(2, 2, 2), (2, 1, 2), (2, 0, 2)]
# H: 995, H_woE: 4457
# random seed is 82
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 3, 1), (2, 3, 2)]
# H: 402, H_woE: 174
# random seed is 83
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 1, 1), (2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 471, H_woE: 430
# random seed is 84
# subgoal Increased, [(2, 2, 2), (2, 2, 1)]
# H: 27, H_woE: 32
# random seed is 85
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 84, H_woE: 85
# random seed is 86
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 28, H_woE: 26
# random seed is 87
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 60, H_woE: 107
# random seed is 88
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1)]
# H: 110, H_woE: 30
# random seed is 89
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 2, 2), (2, 1, 2)]
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 1, 1), (2, 1, 2)]
# H: 131, H_woE: 106
# random seed is 90
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3), (2, 3, 2), (2, 3, 1)]
# H: 145, H_woE: 344
# random seed is 91
# subgoal Increased, [(2, 3, 1)]
# H: 16, H_woE: 18
# random seed is 92
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3), (2, 3, 2), (2, 3, 1), (2, 3, 0)]
# H: 380, H_woE: 616
# random seed is 93
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 1, 1), (2, 0, 1)]
# H: 92, H_woE: 178
# random seed is 94
# subgoal Increased, [(2, 2, 1)]
# H: 13, H_woE: 12
# random seed is 95
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2), (2, 0, 2), (2, 0, 1), (2, 0, 0)]
# H: 1502, H_woE: 1071
# random seed is 96
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# H: 79, H_woE: 166
# random seed is 97
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1), (2, 1, 1), (2, 1, 0), (2, 0, 0)]
# H: 859, H_woE: 414
# random seed is 98
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 2, 2), (2, 2, 3)]
# H: 135, H_woE: 413
# random seed is 99
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 1, 2)]
# H: 55, H_woE: 48
# random seed is 100
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 1, 2), (2, 0, 2), (2, 0, 1), (2, 0, 0)]
# H: 2336, H_woE: 485
# random seed is 101
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 64, H_woE: 124
# random seed is 102
# subgoal Increased, [(2, 3, 2)]
# H: 8, H_woE: 7
# random seed is 103
# subgoal Increased, [(2, 1, 3)]
# H: 14, H_woE: 13
# random seed is 104
# subgoal Increased, [(2, 3, 2), (2, 3, 3)]
# H: 29, H_woE: 32
# random seed is 105
# subgoal Increased, [(2, 2, 0)]
# H: 21, H_woE: 24
# random seed is 106
# subgoal Increased, [(2, 1, 3)]
# H: 35, H_woE: 24
# random seed is 107
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 61, H_woE: 103
# random seed is 108
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 142, H_woE: 60
# random seed is 109
# subgoal Increased, [(2, 2, 2), (2, 2, 1)]
# H: 26, H_woE: 14
# random seed is 111
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 39, H_woE: 43
# random seed is 0
# subgoal Increased, [(2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 52, H_woE: 86
# random seed is 1
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, 2, 1), (2, 3, 1), (2, 3, 0)]
# H: 361, H_woE: 798
# random seed is 2
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 1, 1), (2, 1, 2), (2, 1, 3)]
# H: 692, H_woE: 991
# random seed is 4
# subgoal Increased, [(2, 2, 2), (2, 2, 3), (2, 3, 3)]
# H: 72, H_woE: 75
# random seed is 5
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2), (2, 1, 3), (2, 0, 3)]
# H: 297, H_woE: 293
# random seed is 6
# subgoal Increased, [(2, 1, 2), (2, 0, 2)]
# H: 99, H_woE: 80
# random seed is 7
# subgoal Increased, [(2, 2, 0), (2, 2, 1)]
# H: 21, H_woE: 18
# random seed is 8
# subgoal Increased, [(2, 3, 0), (2, 2, 0), (2, 1, 0)]
# H: 938, H_woE: 45
# random seed is 9
# subgoal Increased, [(2, 2, 2), (2, 2, 1), (2, 1, 1), (2, 1, 0)]
# H: 228, H_woE: 913
# random seed is 10
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 34, H_woE: 23
# random seed is 11
# subgoal Increased, [(2, 2, 1), (2, 3, 1)]
# H: 29, H_woE: 27
# random seed is 12
# subgoal Increased, [(2, 0, 3)]
# H: 21, H_woE: 19
# random seed is 13
# subgoal Increased, [(2, 1, 0), (2, 2, 0)]
# H: 28, H_woE: 25
# random seed is 14
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, 3, 2), (2, 3, 3)]
# H: 211, H_woE: 438
# random seed is 15
# subgoal Increased, [(2, 1, 1)]
# H: 12, H_woE: 9
# random seed is 16
# subgoal Increased, [(2, 1, 0), (2, 0, 0), (2, 0, 1), (2, 0, 2)]
# H: 10000, H_woE: 59
# random seed is 17
# subgoal Increased, [(2, 0, 1), (2, 1, 1), (2, 2, 1)]
# H: 42, H_woE: 63
# random seed is 18
# subgoal Increased, [(2, 2, 1), (2, 2, 0)]
# H: 30, H_woE: 25
# random seed is 20
# subgoal Increased, [(2, 1, 0), (2, 0, 0), (2, 0, 1)]
# H: 284, H_woE: 44
# random seed is 21
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 2, 2), (2, 1, 2)]
# H: 95, H_woE: 185
# random seed is 23
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 1, 2), (2, 0, 2)]
# H: 103, H_woE: 81
# random seed is 24
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 47, H_woE: 79
# random seed is 25
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 2, 1)]
# H: 42, H_woE: 84
# random seed is 26
# subgoal Increased, [(2, 2, 1), (2, 2, 2), (2, 1, 2), (2, 0, 2)]
# H: 110, H_woE: 110
# random seed is 27
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 22, H_woE: 28
# random seed is 28
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 3, 0)]
# H: 63, H_woE: 40
# random seed is 30
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, 2, 3), (2, 3, 3)]
# H: 216, H_woE: 238
# random seed is 31
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3)]
# H: 43, H_woE: 69
# random seed is 32
# subgoal Increased, [(2, 1, 3), (2, 0, 3), (2, 0, 2)]
# H: 59, H_woE: 53
# random seed is 33
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 49, H_woE: 43
# random seed is 34
# subgoal Increased, [(2, 2, 2), (2, 1, 2)]
# H: 56, H_woE: 71
# random seed is 35
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 2, 2), (2, 2, 3)]
# H: 67, H_woE: 192
# random seed is 36
# subgoal Increased, [(2, 1, 0)]
# H: 14, H_woE: 16
# random seed is 38
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 20, H_woE: 16
# random seed is 39
# subgoal Increased, [(2, 3, 3), (2, 2, 3)]
# H: 23, H_woE: 32
# random seed is 40
# subgoal Increased, [(2, 3, 2), (2, 3, 3), (2, 2, 3), (2, 1, 3)]
# H: 76, H_woE: 140
# random seed is 41
# subgoal Increased, [(2, 2, 2)]
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 2, 2)]
# H: 38, H_woE: 42
# random seed is 42
# subgoal Increased, [(2, 0, 0), (2, 0, 1)]
# H: 1987, H_woE: 22
# random seed is 44
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3)]
# H: 291, H_woE: 134
# random seed is 45
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 38, H_woE: 77
# random seed is 46
# subgoal Increased, [(2, 0, 1), (2, 1, 1), (2, 1, 2), (2, 2, 2)]
# H: 79, H_woE: 65
# random seed is 47
# subgoal Increased, [(2, 2, 1)]
# H: 13, H_woE: 10
# random seed is 48
# subgoal Increased, [(2, 1, 3), (2, 1, 2), (2, 1, 1)]
# subgoal Increased, [(2, 2, 2), (2, 1, 2), (2, 1, 1)]
# H: 63, H_woE: 208
# random seed is 49
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 3, 0), (2, 2, 0)]
# H: 57, H_woE: 76
# random seed is 51
# subgoal Increased, [(2, 2, 2), (2, 2, 1), (2, 2, 0)]
# H: 160, H_woE: 768
# random seed is 52
# subgoal Increased, [(2, 3, 0), (2, 2, 0)]
# H: 25, H_woE: 14
# random seed is 53
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 3, 1)]
# H: 120, H_woE: 223
# random seed is 55
# subgoal Increased, [(2, 0, 1), (2, 1, 1)]
# H: 13, H_woE: 15
# random seed is 56
# subgoal Increased, [(2, 2, 0), (2, 2, 1)]
# H: 18, H_woE: 11
# random seed is 57
# subgoal Increased, [(2, 1, 0)]
# H: 7, H_woE: 6
# random seed is 58
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 1, 2), (2, 0, 2), (2, 0, 1)]
# H: 334, H_woE: 146
# random seed is 60
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 31, H_woE: 37
# random seed is 61
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 45, H_woE: 46
# random seed is 63
# subgoal Increased, [(2, 0, 1), (2, 1, 1), (2, 2, 1), (2, 3, 1)]
# H: 125, H_woE: 97
# random seed is 64
# subgoal Increased, [(2, 2, 3), (2, 2, 2)]
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# subgoal Increased, [(2, 0, 3), (2, 1, 3), (2, 2, 3), (2, 2, 2)]
# H: 47, H_woE: 66
# random seed is 65
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 41, H_woE: 48
# random seed is 66
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 2, 0)]
# H: 29, H_woE: 45
# random seed is 67
# subgoal Increased, [(2, 1, 2), (2, 1, 3), (2, 2, 3)]
# H: 343, H_woE: 83
# random seed is 68
# subgoal Increased, [(2, 2, 3)]
# H: 31, H_woE: 24
# random seed is 69
# subgoal Increased, [(2, 3, 1)]
# H: 39, H_woE: 48
# random seed is 70
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2), (2, 1, 1)]
# H: 74, H_woE: 81
# random seed is 71
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 1, 2), (2, 1, 1)]
# H: 72, H_woE: 124
# random seed is 72
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 374, H_woE: 444
# random seed is 73
# subgoal Increased, [(2, 1, 2), (2, 1, 3), (2, 0, 3)]
# H: 52, H_woE: 71
# random seed is 74
# subgoal Increased, [(2, 2, 0), (2, 3, 0)]
# H: 23, H_woE: 20
# random seed is 75
# subgoal Increased, [(2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 41, H_woE: 40
# random seed is 76
# subgoal Increased, [(2, 3, 3), (2, 2, 3)]
# H: 21, H_woE: 15
# random seed is 77
# subgoal Increased, [(2, 3, 1), (2, 3, 0)]
# H: 24, H_woE: 23
# random seed is 78
# subgoal Increased, [(2, 2, 1)]
# H: 98, H_woE: 67
# random seed is 80
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 2, 2), (2, 3, 2), (2, 3, 3)]
# H: 224, H_woE: 492
# random seed is 81
# subgoal Increased, [(2, 0, 2)]
# H: 335, H_woE: 10000
# random seed is 82
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 3, 1), (2, 3, 2)]
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 2, 2), (2, 3, 2)]
# H: 491, H_woE: 160
# random seed is 83
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 1, 1), (2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 537, H_woE: 498
# random seed is 84
# subgoal Increased, [(2, 2, 2), (2, 2, 1)]
# H: 31, H_woE: 34
# random seed is 85
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 334, H_woE: 104
# random seed is 86
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 19, H_woE: 23
# random seed is 87
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 68, H_woE: 125
# random seed is 88
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1)]
# H: 33, H_woE: 32
# random seed is 89
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 1, 1), (2, 1, 2)]
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 2, 2), (2, 1, 2)]
# H: 145, H_woE: 113
# random seed is 90
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3), (2, 3, 2), (2, 3, 1)]
# H: 264, H_woE: 233
# random seed is 91
# subgoal Increased, [(2, 3, 1)]
# H: 16, H_woE: 16
# random seed is 92
# subgoal Increased, [(2, 0, 2), (2, 0, 1), (2, 0, 0), (2, 1, 0), (2, 2, 0), (2, 3, 0)]
# H: 326, H_woE: 395
# random seed is 93
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 1, 1), (2, 0, 1)]
# H: 97, H_woE: 151
# random seed is 94
# subgoal Increased, [(2, 2, 1)]
# H: 9, H_woE: 11
# random seed is 95
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 1, 2), (2, 0, 2), (2, 0, 1), (2, 0, 0)]
# H: 1551, H_woE: 1161
# random seed is 96
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# H: 71, H_woE: 102
# random seed is 97
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2), (2, 0, 2), (2, 0, 1), (2, 0, 0)]
# H: 275, H_woE: 1010
# random seed is 98
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3)]
# H: 146, H_woE: 163
# random seed is 99
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 1, 2)]
# H: 62, H_woE: 50
# random seed is 100
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1), (2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 1112, H_woE: 10000
# random seed is 101
# subgoal Increased, [(2, 2, 2), (2, 3, 2), (2, 3, 3)]
# H: 115, H_woE: 270
# random seed is 102
# subgoal Increased, [(2, 3, 2)]
# H: 11, H_woE: 9
# random seed is 103
# subgoal Increased, [(2, 1, 3)]
# H: 12, H_woE: 12
# random seed is 104
# subgoal Increased, [(2, 3, 2), (2, 3, 3)]
# H: 33, H_woE: 38
# random seed is 105
# subgoal Increased, [(2, 2, 0)]
# H: 28, H_woE: 26
# random seed is 106
# subgoal Increased, [(2, 1, 3)]
# H: 30, H_woE: 27
# random seed is 107
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 57, H_woE: 114
# random seed is 108
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 130, H_woE: 77
# random seed is 109
# subgoal Increased, [(2, 1, 1), (2, 2, 1)]
# H: 24, H_woE: 15
# random seed is 111
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 49, H_woE: 52
# random seed is 0
# subgoal Increased, [(2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 57, H_woE: 90
# random seed is 1
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 1, 1), (2, 2, 1), (2, 3, 1), (2, 3, 0)]
# H: 533, H_woE: 2204
# random seed is 2
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 2, 2), (2, 2, 3), (2, 1, 3)]
# H: 235, H_woE: 223
# random seed is 4
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 63, H_woE: 32
# random seed is 5
# subgoal Increased, [(2, 2, 1), (2, 1, 1), (2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 149, H_woE: 341
# random seed is 6
# subgoal Increased, [(2, 1, 2), (2, 0, 2)]
# H: 98, H_woE: 84
# random seed is 7
# subgoal Increased, [(2, 2, 0), (2, 2, 1)]
# H: 30, H_woE: 16
# random seed is 8
# subgoal Increased, [(2, 2, 1), (2, 1, 1), (2, 1, 0)]
# H: 1070, H_woE: 111
# random seed is 9
# subgoal Increased, [(2, 1, 3), (2, 1, 2), (2, 1, 1), (2, 1, 0)]
# H: 234, H_woE: 1299
# random seed is 10
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 27, H_woE: 21
# random seed is 11
# subgoal Increased, [(2, 2, 1), (2, 3, 1)]
# H: 35, H_woE: 23
# random seed is 12
# subgoal Increased, [(2, 0, 3)]
# H: 19, H_woE: 19
# random seed is 13
# subgoal Increased, [(2, 1, 0), (2, 2, 0)]
# H: 24, H_woE: 30
# random seed is 14
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, 2, 3), (2, 3, 3)]
# H: 199, H_woE: 471
# random seed is 15
# subgoal Increased, [(2, 1, 1)]
# H: 11, H_woE: 14
# random seed is 16
# subgoal Increased, [(2, 1, 0), (2, 0, 0), (2, 0, 1), (2, 0, 2)]
# H: 432, H_woE: 73
# random seed is 17
# subgoal Increased, [(2, 1, 0), (2, 2, 0), (2, 2, 1)]
# H: 42, H_woE: 49
# random seed is 18
# subgoal Increased, [(2, 2, 1), (2, 2, 0)]
# H: 29, H_woE: 39
# random seed is 20
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 0, 1)]
# H: 39, H_woE: 36
# random seed is 21
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 2, 2), (2, 1, 2)]
# H: 64, H_woE: 149
# random seed is 23
# subgoal Increased, [(2, 2, 1), (2, 2, 2), (2, 1, 2), (2, 0, 2)]
# H: 79, H_woE: 83
# random seed is 24
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 51, H_woE: 63
# random seed is 25
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 2, 1)]
# H: 49, H_woE: 71
# random seed is 26
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2), (2, 0, 2)]
# H: 126, H_woE: 206
# random seed is 27
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 17, H_woE: 22
# random seed is 28
# subgoal Increased, [(2, 2, 1), (2, 3, 1), (2, 3, 0)]
# H: 45, H_woE: 71
# random seed is 30
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 2, 2), (2, 3, 2), (2, 3, 3)]
# H: 223, H_woE: 498
# random seed is 31
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3)]
# H: 83, H_woE: 61
# random seed is 32
# subgoal Increased, [(2, 1, 3), (2, 0, 3), (2, 0, 2)]
# H: 57, H_woE: 59
# random seed is 33
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 51, H_woE: 59
# random seed is 34
# subgoal Increased, [(2, 2, 2), (2, 1, 2)]
# H: 53, H_woE: 65
# random seed is 35
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3), (2, 2, 3)]
# H: 59, H_woE: 78
# random seed is 36
# subgoal Increased, [(2, 1, 0)]
# H: 10, H_woE: 12
# random seed is 38
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 23, H_woE: 17
# random seed is 39
# subgoal Increased, [(2, 3, 3), (2, 2, 3)]
# H: 21, H_woE: 23
# random seed is 40
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2), (2, 1, 3)]
# H: 92, H_woE: 85
# random seed is 41
# subgoal Increased, [(2, 2, 2)]
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 2, 2)]
# H: 70, H_woE: 46
# random seed is 42
# subgoal Increased, [(2, 0, 0), (2, 0, 1)]
# subgoal Increased, [(2, 1, 1), (2, 0, 1)]
# H: 19, H_woE: 19
# random seed is 44
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 2, 2), (2, 2, 3)]
# H: 85, H_woE: 218
# random seed is 45
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 37, H_woE: 39
# random seed is 46
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 1, 2), (2, 2, 2)]
# H: 51, H_woE: 81
# random seed is 47
# subgoal Increased, [(2, 2, 1)]
# H: 11, H_woE: 15
# random seed is 48
# subgoal Increased, [(2, 1, 3), (2, 1, 2), (2, 1, 1)]
# subgoal Increased, [(2, 2, 2), (2, 1, 2), (2, 1, 1)]
# H: 65, H_woE: 224
# random seed is 49
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 3, 0), (2, 2, 0)]
# H: 65, H_woE: 78
# random seed is 51
# subgoal Increased, [(2, 2, 2), (2, 2, 1), (2, 2, 0)]
# H: 138, H_woE: 661
# random seed is 52
# subgoal Increased, [(2, 3, 0), (2, 2, 0)]
# H: 25, H_woE: 21
# random seed is 53
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 3, 1)]
# H: 130, H_woE: 209
# random seed is 55
# subgoal Increased, [(2, 0, 1), (2, 1, 1)]
# H: 15, H_woE: 8
# random seed is 56
# subgoal Increased, [(2, 1, 1), (2, 2, 1)]
# H: 14, H_woE: 16
# random seed is 57
# subgoal Increased, [(2, 1, 0)]
# H: 12, H_woE: 8
# random seed is 58
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2), (2, 0, 2), (2, 0, 1)]
# H: 328, H_woE: 182
# random seed is 60
# subgoal Increased, [(2, 3, 1), (2, 3, 2)]
# H: 39, H_woE: 33
# random seed is 61
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 50, H_woE: 40
# random seed is 63
# subgoal Increased, [(2, 1, 2), (2, 1, 1), (2, 2, 1), (2, 3, 1)]
# H: 82, H_woE: 90
# random seed is 64
# subgoal Increased, [(2, 2, 3), (2, 2, 2)]
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# subgoal Increased, [(2, 0, 3), (2, 1, 3), (2, 1, 2), (2, 2, 2)]
# H: 45, H_woE: 68
# random seed is 65
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 40, H_woE: 42
# random seed is 66
# subgoal Increased, [(2, 0, 0), (2, 1, 0), (2, 2, 0)]
# H: 45, H_woE: 24
# random seed is 67
# subgoal Increased, [(2, 1, 2), (2, 1, 3), (2, 2, 3)]
# H: 329, H_woE: 60
# random seed is 68
# subgoal Increased, [(2, 2, 3)]
# H: 23, H_woE: 31
# random seed is 69
# subgoal Increased, [(2, 3, 1)]
# H: 67, H_woE: 40
# random seed is 70
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 1, 2), (2, 1, 1)]
# H: 89, H_woE: 147
# random seed is 71
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1), (2, 1, 1)]
# H: 103, H_woE: 191
# random seed is 72
# subgoal Increased, [(2, 1, 0), (2, 2, 0), (2, 3, 0), (2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 355, H_woE: 611
# random seed is 73
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 57, H_woE: 42
# random seed is 74
# subgoal Increased, [(2, 3, 1), (2, 3, 0)]
# H: 21, H_woE: 23
# random seed is 75
# subgoal Increased, [(2, 1, 2), (2, 1, 3), (2, 0, 3)]
# H: 78, H_woE: 59
# random seed is 76
# subgoal Increased, [(2, 3, 3), (2, 2, 3)]
# H: 18, H_woE: 27
# random seed is 77
# subgoal Increased, [(2, 2, 0), (2, 3, 0)]
# H: 30, H_woE: 19
# random seed is 78
# subgoal Increased, [(2, 2, 1)]
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1)]
# H: 82, H_woE: 71
# random seed is 80
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 2, 2), (2, 2, 3), (2, 3, 3)]
# H: 228, H_woE: 426
# random seed is 81
# subgoal Increased, [(2, 0, 2)]
# subgoal Increased, [(2, 1, 1), (2, 0, 1), (2, 0, 2)]
# subgoal Increased, [(2, 2, 2), (2, 1, 2), (2, 0, 2)]
# H: 773, H_woE: 2503
# random seed is 82
# subgoal Increased, [(2, 2, 0), (2, 3, 0), (2, 3, 1), (2, 3, 2)]
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 3, 1), (2, 3, 2)]
# H: 475, H_woE: 206
# random seed is 83
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 0, 3)]
# H: 341, H_woE: 611
# random seed is 84
# subgoal Increased, [(2, 2, 2), (2, 2, 1)]
# H: 33, H_woE: 35
# random seed is 85
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 637, H_woE: 85
# random seed is 86
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 31, H_woE: 26
# random seed is 87
# subgoal Increased, [(2, 1, 2), (2, 0, 2), (2, 0, 3)]
# H: 61, H_woE: 98
# random seed is 88
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1)]
# H: 33, H_woE: 28
# random seed is 89
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 1, 1), (2, 1, 2)]
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 2, 2), (2, 1, 2)]
# H: 111, H_woE: 90
# random seed is 90
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3), (2, 3, 2), (2, 3, 1)]
# H: 545, H_woE: 266
# random seed is 91
# subgoal Increased, [(2, 3, 1)]
# H: 18, H_woE: 17
# random seed is 92
# subgoal Increased, [(2, 0, 2), (2, 0, 1), (2, 1, 1), (2, 2, 1), (2, 3, 1), (2, 3, 0)]
# H: 593, H_woE: 749
# random seed is 93
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 0, 0), (2, 0, 1)]
# H: 92, H_woE: 306
# random seed is 94
# subgoal Increased, [(2, 2, 1)]
# H: 13, H_woE: 13
# random seed is 95
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 2, 1), (2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 1669, H_woE: 1774
# random seed is 96
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# H: 81, H_woE: 95
# random seed is 97
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1), (2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 931, H_woE: 514
# random seed is 98
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 2, 2), (2, 2, 3)]
# H: 143, H_woE: 487
# random seed is 99
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 1, 2)]
# H: 53, H_woE: 48
# random seed is 100
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2), (2, 0, 2), (2, 0, 1), (2, 0, 0)]
# H: 1068, H_woE: 551
# random seed is 101
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 89, H_woE: 98
# random seed is 102
# subgoal Increased, [(2, 3, 2)]
# H: 10, H_woE: 10
# random seed is 103
# subgoal Increased, [(2, 1, 3)]
# H: 12, H_woE: 14
# random seed is 104
# subgoal Increased, [(2, 3, 2), (2, 3, 3)]
# H: 34, H_woE: 35
# random seed is 105
# subgoal Increased, [(2, 2, 0)]
# H: 39, H_woE: 38
# random seed is 106
# subgoal Increased, [(2, 1, 3)]
# H: 23, H_woE: 27
# random seed is 107
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 58, H_woE: 111
# random seed is 108
# subgoal Increased, [(2, 2, 2), (2, 2, 3), (2, 3, 3)]
# H: 63, H_woE: 68
# random seed is 109
# subgoal Increased, [(2, 1, 1), (2, 2, 1)]
# H: 21, H_woE: 18
# random seed is 111
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 36, H_woE: 37
# random seed is 0
# subgoal Increased, [(2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 58, H_woE: 78
# random seed is 1
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, 3, 2), (2, 3, 1), (2, 3, 0)]
# H: 549, H_woE: 531
# random seed is 2
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3), (2, 2, 3), (2, 1, 3)]
# H: 145, H_woE: 194
# random seed is 4
# subgoal Increased, [(2, 2, 2), (2, 2, 3), (2, 3, 3)]
# H: 51, H_woE: 78
# random seed is 5
# subgoal Increased, [(2, 2, 1), (2, 2, 2), (2, 1, 2), (2, 0, 2), (2, 0, 3)]
# H: 172, H_woE: 366
# random seed is 6
# subgoal Increased, [(2, 1, 2), (2, 0, 2)]
# H: 98, H_woE: 84
# random seed is 7
# subgoal Increased, [(2, 2, 0), (2, 2, 1)]
# H: 23, H_woE: 19
# random seed is 8
# subgoal Increased, [(2, 2, 1), (2, 2, 0), (2, 1, 0)]
# H: 34, H_woE: 73
# random seed is 9
# subgoal Increased, [(2, 2, 2), (2, 2, 1), (2, 2, 0), (2, 1, 0)]
# H: 224, H_woE: 1088
# random seed is 10
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 23, H_woE: 20
# random seed is 11
# subgoal Increased, [(2, 2, 1), (2, 3, 1)]
# H: 37, H_woE: 32
# random seed is 12
# subgoal Increased, [(2, 0, 3)]
# H: 16, H_woE: 18
# random seed is 13
# subgoal Increased, [(2, 1, 0), (2, 2, 0)]
# H: 27, H_woE: 26
# random seed is 14
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 697, H_woE: 233
# random seed is 15
# subgoal Increased, [(2, 1, 1)]
# H: 14, H_woE: 12
# random seed is 16
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 1, 2), (2, 0, 2)]
# H: 10000, H_woE: 196
# random seed is 17
# subgoal Increased, [(2, 1, 0), (2, 2, 0), (2, 2, 1)]
# H: 42, H_woE: 40
# random seed is 18
# subgoal Increased, [(2, 2, 1), (2, 2, 0)]
# H: 35, H_woE: 33
# random seed is 20
# subgoal Increased, [(2, 1, 0), (2, 0, 0), (2, 0, 1)]
# H: 44, H_woE: 44
# random seed is 21
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 2, 2), (2, 1, 2)]
# H: 92, H_woE: 152
# random seed is 23
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 0, 1), (2, 0, 2)]
# H: 76, H_woE: 117
# random seed is 24
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 54, H_woE: 62
# random seed is 25
# subgoal Increased, [(2, 1, 2), (2, 1, 1), (2, 2, 1)]
# H: 56, H_woE: 48
# random seed is 26
# subgoal Increased, [(2, 2, 1), (2, 1, 1), (2, 0, 1), (2, 0, 2)]
# H: 153, H_woE: 128
# random seed is 27
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 16, H_woE: 21
# random seed is 28
# subgoal Increased, [(2, 2, 1), (2, 3, 1), (2, 3, 0)]
# H: 55, H_woE: 61
# random seed is 30
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 369, H_woE: 226
# random seed is 31
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3)]
# H: 50, H_woE: 42
# random seed is 32
# subgoal Increased, [(2, 1, 3), (2, 1, 2), (2, 0, 2)]
# H: 57, H_woE: 50
# random seed is 33
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 50, H_woE: 43
# random seed is 34
# subgoal Increased, [(2, 2, 2), (2, 1, 2)]
# H: 56, H_woE: 69
# random seed is 35
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3), (2, 2, 3)]
# H: 69, H_woE: 82
# random seed is 36
# subgoal Increased, [(2, 1, 0)]
# H: 12, H_woE: 9
# random seed is 38
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 20, H_woE: 22
# random seed is 39
# subgoal Increased, [(2, 3, 3), (2, 2, 3)]
# H: 26, H_woE: 25
# random seed is 40
# subgoal Increased, [(2, 2, 1), (2, 1, 1), (2, 1, 2), (2, 1, 3)]
# H: 107, H_woE: 316
# random seed is 41
# subgoal Increased, [(2, 2, 2)]
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 2, 2)]
# H: 59, H_woE: 45
# random seed is 42
# subgoal Increased, [(2, 1, 1), (2, 0, 1)]
# subgoal Increased, [(2, 0, 0), (2, 0, 1)]
# H: 22, H_woE: 28
# random seed is 44
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3)]
# H: 187, H_woE: 128
# random seed is 45
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 4376, H_woE: 40
# random seed is 46
# subgoal Increased, [(2, 1, 0), (2, 2, 0), (2, 2, 1), (2, 2, 2)]
# H: 62, H_woE: 50
# random seed is 47
# subgoal Increased, [(2, 2, 1)]
# H: 8, H_woE: 13
# random seed is 48
# subgoal Increased, [(2, 2, 2), (2, 2, 1), (2, 1, 1)]
# H: 124, H_woE: 60
# random seed is 49
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 2, 1), (2, 2, 0)]
# H: 56, H_woE: 425
# random seed is 51
# subgoal Increased, [(2, 2, 2), (2, 2, 1), (2, 2, 0)]
# H: 156, H_woE: 587
# random seed is 52
# subgoal Increased, [(2, 3, 0), (2, 2, 0)]
# H: 15, H_woE: 22
# random seed is 53
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 3, 1)]
# H: 113, H_woE: 198
# random seed is 55
# subgoal Increased, [(2, 0, 1), (2, 1, 1)]
# H: 16, H_woE: 15
# random seed is 56
# subgoal Increased, [(2, 2, 0), (2, 2, 1)]
# H: 14, H_woE: 11
# random seed is 57
# subgoal Increased, [(2, 1, 0)]
# H: 12, H_woE: 8
# random seed is 58
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 1, 2), (2, 1, 1), (2, 0, 1)]
# H: 350, H_woE: 206
# random seed is 60
# subgoal Increased, [(2, 3, 1), (2, 3, 2)]
# H: 39, H_woE: 37
# random seed is 61
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 41, H_woE: 44
# random seed is 63
# subgoal Increased, [(2, 1, 2), (2, 1, 1), (2, 2, 1), (2, 3, 1)]
# H: 167, H_woE: 123
# random seed is 64
# subgoal Increased, [(2, 2, 3), (2, 2, 2)]
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# subgoal Increased, [(2, 0, 3), (2, 1, 3), (2, 2, 3), (2, 2, 2)]
# H: 71, H_woE: 84
# random seed is 65
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 36, H_woE: 48
# random seed is 66
# subgoal Increased, [(2, 1, 1), (2, 1, 0), (2, 2, 0)]
# H: 23, H_woE: 30
# random seed is 67
# subgoal Increased, [(2, 1, 2), (2, 2, 2), (2, 2, 3)]
# H: 305, H_woE: 55
# random seed is 68
# subgoal Increased, [(2, 2, 3)]
# H: 25, H_woE: 26
# random seed is 69
# subgoal Increased, [(2, 3, 1)]
# H: 39, H_woE: 70
# random seed is 70
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2), (2, 1, 1)]
# H: 245, H_woE: 62
# random seed is 71
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 1, 2), (2, 1, 1)]
# H: 91, H_woE: 100
# random seed is 72
# subgoal Increased, [(2, 0, 1), (2, 0, 2), (2, 0, 3), (2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 424, H_woE: 439
# random seed is 73
# subgoal Increased, [(2, 1, 2), (2, 1, 3), (2, 0, 3)]
# H: 106, H_woE: 60
# random seed is 74
# subgoal Increased, [(2, 2, 0), (2, 3, 0)]
# H: 26, H_woE: 19
# random seed is 75
# subgoal Increased, [(2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 51, H_woE: 48
# random seed is 76
# subgoal Increased, [(2, 3, 3), (2, 2, 3)]
# H: 17, H_woE: 20
# random seed is 77
# subgoal Increased, [(2, 2, 0), (2, 3, 0)]
# H: 25, H_woE: 19
# random seed is 78
# subgoal Increased, [(2, 2, 1)]
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 2, 1)]
# H: 101, H_woE: 86
# random seed is 80
# subgoal Increased, [(2, 0, 2), (2, 0, 3), (2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 278, H_woE: 198
# random seed is 81
# subgoal Increased, [(2, 0, 2)]
# H: 987, H_woE: 10000
# random seed is 82
# subgoal Increased, [(2, 2, 0), (2, 3, 0), (2, 3, 1), (2, 3, 2)]
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 3, 1), (2, 3, 2)]
# H: 448, H_woE: 179
# random seed is 83
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 2, 2), (2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 573, H_woE: 1138
# random seed is 84
# subgoal Increased, [(2, 2, 2), (2, 2, 1)]
# H: 34, H_woE: 24
# random seed is 85
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 615, H_woE: 97
# random seed is 86
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 20, H_woE: 22
# random seed is 87
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 62, H_woE: 101
# random seed is 88
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1)]
# H: 35, H_woE: 31
# random seed is 89
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 2, 2), (2, 1, 2)]
# H: 154, H_woE: 80
# random seed is 90
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, 3, 2), (2, 3, 1)]
# H: 122, H_woE: 406
# random seed is 91
# subgoal Increased, [(2, 3, 1)]
# H: 21, H_woE: 18
# random seed is 92
# subgoal Increased, [(2, 1, 3), (2, 1, 2), (2, 1, 1), (2, 1, 0), (2, 2, 0), (2, 3, 0)]
# H: 551, H_woE: 852
# random seed is 93
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 1, 1), (2, 0, 1)]
# H: 89, H_woE: 201
# random seed is 94
# subgoal Increased, [(2, 2, 1)]
# H: 12, H_woE: 12
# random seed is 95
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 3, 0), (2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 868, H_woE: 1315
# random seed is 96
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# H: 75, H_woE: 96
# random seed is 97
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 1, 2), (2, 0, 2), (2, 0, 1), (2, 0, 0)]
# H: 274, H_woE: 858
# random seed is 98
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3)]
# H: 108, H_woE: 237
# random seed is 99
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 1, 2)]
# H: 37, H_woE: 43
# random seed is 100
# subgoal Increased, [(2, 2, 3), (2, 2, 2), (2, 2, 1), (2, 1, 1), (2, 0, 1), (2, 0, 0)]
# H: 2368, H_woE: 1498
# random seed is 101
# subgoal Increased, [(2, 2, 2), (2, 3, 2), (2, 3, 3)]
# H: 60, H_woE: 263
# random seed is 102
# subgoal Increased, [(2, 3, 2)]
# H: 7, H_woE: 9
# random seed is 103
# subgoal Increased, [(2, 1, 3)]
# H: 17, H_woE: 13
# random seed is 104
# subgoal Increased, [(2, 3, 2), (2, 3, 3)]
# H: 26, H_woE: 37
# random seed is 105
# subgoal Increased, [(2, 2, 0)]
# H: 27, H_woE: 27
# random seed is 106
# subgoal Increased, [(2, 1, 3)]
# H: 27, H_woE: 27
# random seed is 107
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 68, H_woE: 95
# random seed is 108
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 64, H_woE: 60
# random seed is 109
# subgoal Increased, [(2, 1, 1), (2, 2, 1)]
# H: 32, H_woE: 15
# random seed is 111
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 45, H_woE: 44

# %%
df_success = pd.DataFrame(success_data)

df_success_rate = pd.DataFrame({
    'without Extendable': [df_success['H_woE'].mean()],
    'with Extendable': [df_success['H'].mean()]
}, index=['H-MCTS'])

print(df_success_rate)
# Out:
#         without Extendable  with Extendable
# H-MCTS                0.99            0.994

# %%
import numpy as np
import matplotlib.pyplot as plt

# Filter the iteration_data based on success
filtered_iteration_data = {module: [] for module in modules}

for i in range(len(success_data['H_woE'])):
    if all([success_data[module][i] for module in modules]):
        for module in modules:
            filtered_iteration_data[module].append(iteration_data[module][i])

# Calculate mean and standard deviation
mean_data = {module: np.mean(filtered_iteration_data[module]) for module in modules}
std_data = {module: np.std(filtered_iteration_data[module]) for module in modules}

# Plotting the mean and standard deviation
labels = list(mean_data.keys())
mean_vals = list(mean_data.values())
std_vals = list(std_data.values())

x = np.arange(len(labels))  # the label locations

colors = ['blue', 'green', 'red', 'purple']  # Define colors for each module

fig, ax = plt.subplots()
for i in range(len(labels)):
    # Only positive error bars
    ax.bar(x[i], mean_vals[i], yerr=[[0], [std_vals[i]]], color=colors[i], capsize=10)

ax.set_yscale('log') # Change y-axis to log scale

# Remaining part of the code
ax.set_ylabel('Iterations until find the path')
ax.set_title('Extendable ablation')
ax.set_xticks(x)
ax.set_xticklabels(labels)

fig.tight_layout()

plt.show()
