# %%
from src.Planners.H_MCTS_HW import H_MCTS_HW
from src.Planners.H_MCTS_wo_Extendable.H_MCTS import H_MCTS

import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
l1_rows = 8
l1_cols = 8
l1_width = 2
l1_height = 2
# H_level = 2
num_barrier = 15
random_seed= 25

explorationConstant = 1 / math.sqrt(2)
grid_setting = (l1_rows, l1_cols, l1_width, l1_height)

iter_Limit = 10000
H_level = 2

# %%
r = 0
dead_list = [3, 19, 22, 29, 37, 43, 50, 54, 59, 62, 79, 110]  # unfeasible set

num_set = 5

success_data = dict()
iteration_data = dict()

modules = ['H_woE', 'H']

for module in modules:
    success_data[module] = []
    iteration_data[module] = []

Success_H = 0
Success_Plain = 0

H_level = 2
Plain_level = 1
for i in range(1):
    for random_seed in range(0, 112):
    # for random_seed in range(6, 7):

        if random_seed in dead_list:
            continue
        else:
            print(f'random seed is {random_seed}')
            H_mcts = H_MCTS_HW(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
            H_mcts_woE = H_MCTS(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
            
            H_traj, H_success, H_iter = H_mcts.search()
            H_woE_traj, H_woE_success, H_woE_iter = H_mcts_woE.search()
            
            print(f'H: {H_iter}, H_woE: {H_woE_iter}')
            
            success_data['H'].append(H_success)
            success_data['H_woE'].append(H_woE_success)

            iteration_data['H'].append(H_iter)
            iteration_data['H_woE'].append(H_woE_iter)
# Out:
# random seed is 0
# subgoal Increased, [(2, 0, 1), (2, 0, 2), (2, 0, 3)]
# H: 86, H_woE: 92
# random seed is 1
# subgoal Increased, [(2, 1, 3), (2, 1, 2), (2, 2, 2), (2, 3, 2), (2, 3, 1), (2, 3, 0)]
# H: 819, H_woE: 457
# random seed is 2
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3), (2, 2, 3), (2, 1, 3)]
# H: 1001, H_woE: 225
# random seed is 4
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 44, H_woE: 38
# random seed is 5
# subgoal Increased, [(2, 2, 1), (2, 2, 2), (2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 359, H_woE: 433
# random seed is 6
# subgoal Increased, [(2, 1, 2), (2, 0, 2)]
# H: 100, H_woE: 80
# random seed is 7
# subgoal Increased, [(2, 2, 0), (2, 2, 1)]
# H: 17, H_woE: 17
# random seed is 8
# subgoal Increased, [(2, 2, 1), (2, 2, 0), (2, 1, 0)]
# H: 49, H_woE: 72
# random seed is 9
# subgoal Increased, [(2, 2, 2), (2, 1, 2), (2, 1, 1), (2, 1, 0)]
# H: 420, H_woE: 938
# random seed is 10
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 33, H_woE: 33
# random seed is 11
# subgoal Increased, [(2, 2, 1), (2, 3, 1)]
# H: 39, H_woE: 35
# random seed is 12
# subgoal Increased, [(2, 0, 3)]
# H: 16, H_woE: 22
# random seed is 13
# subgoal Increased, [(2, 1, 0), (2, 2, 0)]
# H: 29, H_woE: 26
# random seed is 14
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, 2, 3), (2, 3, 3)]
# H: 1020, H_woE: 419
# random seed is 15
# subgoal Increased, [(2, 1, 1)]
# H: 18, H_woE: 12
# random seed is 16
# subgoal Increased, [(2, 1, 0), (2, 0, 0), (2, 0, 1), (2, 0, 2)]
# H: 296, H_woE: 52
# random seed is 17
# subgoal Increased, [(2, 1, 0), (2, 2, 0), (2, 2, 1)]
# H: 43, H_woE: 41
# random seed is 18
# subgoal Increased, [(2, 2, 1), (2, 2, 0)]
# H: 32, H_woE: 47
# random seed is 20
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 0, 1)]
# H: 52, H_woE: 42
# random seed is 21
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 1, 1), (2, 1, 2)]
# H: 109, H_woE: 149
# random seed is 23
# subgoal Increased, [(2, 1, 0), (2, 1, 1), (2, 0, 1), (2, 0, 2)]
# H: 83, H_woE: 114
# random seed is 24
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 82, H_woE: 78
# random seed is 25
# subgoal Increased, [(2, 1, 2), (2, 2, 2), (2, 2, 1)]
# H: 72, H_woE: 68
# random seed is 26
# subgoal Increased, [(2, 2, 1), (2, 2, 2), (2, 1, 2), (2, 0, 2)]
# H: 173, H_woE: 106
# random seed is 27
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 16, H_woE: 14
# random seed is 28
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 3, 0)]
# H: 58, H_woE: 50
# random seed is 30
# subgoal Increased, [(2, 0, 2), (2, 1, 2), (2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 1223, H_woE: 230
# random seed is 31
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3)]
# H: 85, H_woE: 54
# random seed is 32
# subgoal Increased, [(2, 2, 2), (2, 1, 2), (2, 0, 2)]
# H: 69, H_woE: 158
# random seed is 33
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 52, H_woE: 44
# random seed is 34
# subgoal Increased, [(2, 2, 2), (2, 1, 2)]
# H: 75, H_woE: 68
# random seed is 35
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 2, 2), (2, 2, 3)]
# H: 235, H_woE: 171
# random seed is 36
# subgoal Increased, [(2, 1, 0)]
# H: 14, H_woE: 16
# random seed is 38
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 18, H_woE: 25
# random seed is 39
# subgoal Increased, [(2, 3, 3), (2, 2, 3)]
# H: 21, H_woE: 31
# random seed is 40
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 2, 3), (2, 1, 3)]
# H: 769, H_woE: 103
# random seed is 41
# subgoal Increased, [(2, 2, 2)]
# H: 64, H_woE: 58
# random seed is 42
# subgoal Increased, [(2, 0, 0), (2, 0, 1)]
# H: 17, H_woE: 18
# random seed is 44
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 2, 2), (2, 2, 3)]
# H: 156, H_woE: 113
# random seed is 45
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# subgoal Increased, [(2, 3, 3), (2, 3, 2)]
# H: 45, H_woE: 78
# random seed is 46
# subgoal Increased, [(2, 0, 1), (2, 1, 1), (2, 1, 2), (2, 2, 2)]
# H: 78, H_woE: 65
# random seed is 47
# subgoal Increased, [(2, 2, 1)]
# H: 15, H_woE: 16
# random seed is 48
# subgoal Increased, [(2, 2, 2), (2, 2, 1), (2, 1, 1)]
# H: 150, H_woE: 63
# random seed is 49
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 3, 0), (2, 2, 0)]
# H: 86, H_woE: 70
# random seed is 51
# subgoal Increased, [(2, 2, 2), (2, 2, 1), (2, 2, 0)]
# H: 656, H_woE: 588
# random seed is 52
# subgoal Increased, [(2, 3, 0), (2, 2, 0)]
# H: 20, H_woE: 17
# random seed is 53
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 3, 1)]
# H: 293, H_woE: 220
# random seed is 55
# subgoal Increased, [(2, 0, 1), (2, 1, 1)]
# H: 11, H_woE: 8
# random seed is 56
# subgoal Increased, [(2, 1, 1), (2, 2, 1)]
# H: 14, H_woE: 14
# random seed is 57
# subgoal Increased, [(2, 1, 0)]
# H: 6, H_woE: 6
# random seed is 58
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3), (2, 0, 2), (2, 0, 1)]
# H: 154, H_woE: 124
# random seed is 60
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 34, H_woE: 38
# random seed is 61
# subgoal Increased, [(2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 41, H_woE: 37
# random seed is 63
# subgoal Increased, [(2, 1, 2), (2, 2, 2), (2, 3, 2), (2, 3, 1)]
# H: 94, H_woE: 196
# random seed is 64
# subgoal Increased, [(2, 2, 3), (2, 2, 2)]
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# subgoal Increased, [(2, 0, 3), (2, 1, 3), (2, 1, 2), (2, 2, 2)]
# H: 103, H_woE: 88
# random seed is 65
# subgoal Increased, [(2, 2, 3), (2, 3, 3)]
# H: 49, H_woE: 47
# random seed is 66
# subgoal Increased, [(2, 1, 1), (2, 1, 0), (2, 2, 0)]
# H: 56, H_woE: 35
# random seed is 67
# subgoal Increased, [(2, 1, 2), (2, 2, 2), (2, 2, 3)]
# H: 152, H_woE: 46
# random seed is 68
# subgoal Increased, [(2, 2, 3)]
# H: 23, H_woE: 31
# random seed is 69
# subgoal Increased, [(2, 3, 1)]
# H: 37, H_woE: 35
# random seed is 70
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1), (2, 1, 1)]
# H: 84, H_woE: 137
# random seed is 71
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1), (2, 1, 1)]
# H: 133, H_woE: 173
# random seed is 72
# subgoal Increased, [(2, 1, 0), (2, 2, 0), (2, 2, 1), (2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 708, H_woE: 562
# random seed is 73
# subgoal Increased, [(2, 1, 2), (2, 1, 3), (2, 0, 3)]
# H: 45, H_woE: 66
# random seed is 74
# subgoal Increased, [(2, 3, 1), (2, 3, 0)]
# H: 21, H_woE: 26
# random seed is 75
# subgoal Increased, [(2, 1, 2), (2, 1, 3), (2, 0, 3)]
# H: 55, H_woE: 57
# random seed is 76
# subgoal Increased, [(2, 2, 2), (2, 2, 3)]
# H: 18, H_woE: 25
# random seed is 77
# subgoal Increased, [(2, 3, 1), (2, 3, 0)]
# H: 23, H_woE: 26
# random seed is 78
# subgoal Increased, [(2, 2, 1)]
# H: 93, H_woE: 69
# random seed is 80
# subgoal Increased, [(2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 2, 3), (2, 3, 3)]
# H: 210, H_woE: 291
# random seed is 81
# subgoal Increased, [(2, 0, 2)]
# H: 4601, H_woE: 10000
# random seed is 82
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 3, 1), (2, 3, 2)]
# H: 439, H_woE: 181
# random seed is 83
# subgoal Increased, [(2, 3, 1), (2, 2, 1), (2, 2, 2), (2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 435, H_woE: 1384
# random seed is 84
# subgoal Increased, [(2, 2, 2), (2, 2, 1)]
# H: 35, H_woE: 30
# random seed is 85
# subgoal Increased, [(2, 2, 2), (2, 3, 2)]
# H: 78, H_woE: 105
# random seed is 86
# subgoal Increased, [(2, 1, 2), (2, 1, 1)]
# H: 26, H_woE: 27
# random seed is 87
# subgoal Increased, [(2, 1, 2), (2, 0, 2), (2, 0, 3)]
# H: 88, H_woE: 81
# random seed is 88
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 2, 1)]
# H: 173, H_woE: 31
# random seed is 89
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 2, 2), (2, 1, 2)]
# H: 181, H_woE: 79
# random seed is 90
# subgoal Increased, [(2, 1, 3), (2, 2, 3), (2, 3, 3), (2, 3, 2), (2, 3, 1)]
# H: 274, H_woE: 310
# random seed is 91
# subgoal Increased, [(2, 3, 1)]
# H: 20, H_woE: 18
# random seed is 92
# subgoal Increased, [(2, 0, 2), (2, 0, 1), (2, 0, 0), (2, 1, 0), (2, 2, 0), (2, 3, 0)]
# H: 1529, H_woE: 446
# random seed is 93
# subgoal Increased, [(2, 2, 0), (2, 2, 1), (2, 1, 1), (2, 0, 1)]
# H: 331, H_woE: 154
# random seed is 94
# subgoal Increased, [(2, 2, 1)]
# H: 14, H_woE: 11
# random seed is 95
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3), (2, 0, 2), (2, 0, 1), (2, 0, 0)]
# H: 2134, H_woE: 1140
# random seed is 96
# subgoal Increased, [(2, 1, 2), (2, 2, 2)]
# H: 190, H_woE: 164
# random seed is 97
# subgoal Increased, [(2, 3, 2), (2, 3, 1), (2, 2, 1), (2, 2, 0), (2, 1, 0), (2, 0, 0)]
# H: 2594, H_woE: 426
# random seed is 98
# subgoal Increased, [(2, 1, 1), (2, 2, 1), (2, 2, 2), (2, 2, 3)]
# H: 209, H_woE: 462
# random seed is 99
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 1, 2)]
# H: 54, H_woE: 54
# random seed is 100
# subgoal Increased, [(2, 3, 2), (2, 2, 2), (2, 2, 1), (2, 1, 1), (2, 0, 1), (2, 0, 0)]
# H: 4238, H_woE: 1467
# random seed is 101
# subgoal Increased, [(2, 2, 2), (2, 3, 2), (2, 3, 3)]
# H: 136, H_woE: 266
# random seed is 102
# subgoal Increased, [(2, 3, 2)]
# H: 10, H_woE: 10
# random seed is 103
# subgoal Increased, [(2, 1, 3)]
# H: 12, H_woE: 15
# random seed is 104
# subgoal Increased, [(2, 3, 2), (2, 3, 3)]
# H: 34, H_woE: 35
# random seed is 105
# subgoal Increased, [(2, 2, 0)]
# H: 43, H_woE: 20
# random seed is 106
# subgoal Increased, [(2, 1, 3)]
# H: 27, H_woE: 31
# random seed is 107
# subgoal Increased, [(2, 1, 2), (2, 0, 2), (2, 0, 3)]
# subgoal Increased, [(2, 2, 3), (2, 1, 3), (2, 0, 3)]
# H: 102, H_woE: 230
# random seed is 108
# subgoal Increased, [(2, 2, 2), (2, 3, 2), (2, 3, 3)]
# H: 203, H_woE: 56
# random seed is 109
# subgoal Increased, [(2, 1, 1), (2, 2, 1)]
# H: 24, H_woE: 15
# random seed is 111
# subgoal Increased, [(2, 3, 1), (2, 3, 2), (2, 3, 3)]
# H: 57, H_woE: 64

# %%
df_success = pd.DataFrame(success_data)

df_success_rate = pd.DataFrame({
    'without Extendable': [df_success['H_woE'].mean()],
    'with Extendable': [df_success['H'].mean()]
}, index=['H-MCTS'])

print(df_success_rate)
# Out:
#         without Extendable  with Extendable
# H-MCTS                0.99              1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# Filter the iteration_data based on success
filtered_iteration_data = {module: [] for module in modules}

for i in range(len(success_data['H_woE'])):
    if all([success_data[module][i] for module in modules]):
        for module in modules:
            filtered_iteration_data[module].append(iteration_data[module][i])

# Calculate mean and standard deviation
mean_data = {module: np.mean(filtered_iteration_data[module]) for module in modules}
std_data = {module: np.std(filtered_iteration_data[module]) for module in modules}

# Plotting the mean and standard deviation
labels = list(mean_data.keys())
mean_vals = list(mean_data.values())
std_vals = list(std_data.values())

x = np.arange(len(labels))  # the label locations

colors = ['blue', 'green', 'red', 'purple']  # Define colors for each module

fig, ax = plt.subplots()
for i in range(len(labels)):
    # Only positive error bars
    ax.bar(x[i], mean_vals[i], yerr=[[0], [std_vals[i]]], color=colors[i], capsize=10)

ax.set_yscale('log') # Change y-axis to log scale

# Remaining part of the code
ax.set_ylabel('Iterations until find the path')
ax.set_title('Extendable ablation')
ax.set_xticks(x)
ax.set_xticklabels(labels)

fig.tight_layout()

plt.show()
