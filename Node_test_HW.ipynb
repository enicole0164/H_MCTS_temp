# %% [markdown]
# ### H_tree check

# %%
from src.Planners.H_MCTS_HW import H_MCTS_HW

import math
import pandas as pd

# %%
l1_rows = 8
l1_cols = 8
l1_width = 2
l1_height = 2
# H_level = 2
num_barrier = 16
random_seed= 25

explorationConstant = 1 / math.sqrt(2)
grid_setting = (l1_rows, l1_cols, l1_width, l1_height)

iter_Limit = 10000
H_level = 2

# %%
r = 0
dead_list = [37, 59, 62]  # unfeasible set

total_H = []
total_plain = []

for random_seed in range(0, 51):
    if random_seed in dead_list:
        continue
    else:
        print(f'{random_seed} map')
        
        H_level = 2
        H_mcts = H_MCTS_HW(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
        H_mcts.env.plot_grid(1)
        H_traj, H_success, H_iter = H_mcts.search()
        
        H_level = 1
        Plain_mcts = H_MCTS_HW(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
        Plain_traj, Plain_success, Plain_iter = Plain_mcts.search()

        #print(f'{random_seed} with {H_traj} H-MCTS')
        total_H.append(H_reward)
        # print(mcts.success_traj[2])
        
        if H_success and not Plain_success:
            print('ONLY H-MCTS SUCCEED')
            print(H_traj, H_iter)
            
        elif H_success and Plain_success:
            print(f"BOTH SUCCEED WITH H: {H_iter}, PLAIN: {Plain_iter}")
        
        elif not H_success and Plain_success:
            print('ONLY PLAIN-MCTS SUCCEED')
            print(Plain_traj, Plain_iter)
        
        else:
            print('BOTH FAILED')
        print('-------------------------------------------------------------------------------')
# Out:
# 0 map
# BOTH SUCCEED WITH H: 98, PLAIN: 90
# -------------------------------------------------------------------------------
# 1 map
# BOTH SUCCEED WITH H: 2103, PLAIN: 3146
# -------------------------------------------------------------------------------
# 2 map
# BOTH SUCCEED WITH H: 73, PLAIN: 129
# -------------------------------------------------------------------------------
# 3 map
# BOTH SUCCEED WITH H: 137, PLAIN: 178
# -------------------------------------------------------------------------------
# 4 map
# BOTH SUCCEED WITH H: 379, PLAIN: 327
# -------------------------------------------------------------------------------
# 5 map
# BOTH SUCCEED WITH H: 979, PLAIN: 789
# -------------------------------------------------------------------------------
# 6 map
# BOTH SUCCEED WITH H: 367, PLAIN: 285
# -------------------------------------------------------------------------------
# 7 map
# BOTH SUCCEED WITH H: 801, PLAIN: 1634
# -------------------------------------------------------------------------------
# 8 map
# BOTH SUCCEED WITH H: 113, PLAIN: 173
# -------------------------------------------------------------------------------
# 9 map
# BOTH SUCCEED WITH H: 3876, PLAIN: 3872
# -------------------------------------------------------------------------------
# 10 map
# BOTH SUCCEED WITH H: 538, PLAIN: 549
# -------------------------------------------------------------------------------
# 11 map
# BOTH SUCCEED WITH H: 16, PLAIN: 21
# -------------------------------------------------------------------------------
# 12 map
# BOTH SUCCEED WITH H: 153, PLAIN: 213
# -------------------------------------------------------------------------------
# 13 map
# BOTH SUCCEED WITH H: 56, PLAIN: 57
# -------------------------------------------------------------------------------
# 14 map
# BOTH SUCCEED WITH H: 3484, PLAIN: 5058
# -------------------------------------------------------------------------------
# 15 map
# BOTH SUCCEED WITH H: 18, PLAIN: 24
# -------------------------------------------------------------------------------
# 16 map
# BOTH SUCCEED WITH H: 16, PLAIN: 12
# -------------------------------------------------------------------------------
# 17 map
# BOTH SUCCEED WITH H: 118, PLAIN: 112
# -------------------------------------------------------------------------------
# 18 map
# BOTH SUCCEED WITH H: 175, PLAIN: 196
# -------------------------------------------------------------------------------
# 19 map
# BOTH SUCCEED WITH H: 452, PLAIN: 775
# -------------------------------------------------------------------------------
# 20 map
# BOTH SUCCEED WITH H: 263, PLAIN: 860
# -------------------------------------------------------------------------------
# 21 map
# BOTH SUCCEED WITH H: 66, PLAIN: 49
# -------------------------------------------------------------------------------
# 22 map
# BOTH SUCCEED WITH H: 23, PLAIN: 22
# -------------------------------------------------------------------------------
# 23 map
# BOTH SUCCEED WITH H: 13, PLAIN: 18
# -------------------------------------------------------------------------------
# 24 map
# BOTH SUCCEED WITH H: 1553, PLAIN: 1860
# -------------------------------------------------------------------------------
# 25 map
# BOTH SUCCEED WITH H: 333, PLAIN: 369
# -------------------------------------------------------------------------------
# 26 map
# BOTH SUCCEED WITH H: 64, PLAIN: 61
# -------------------------------------------------------------------------------
# 27 map
# BOTH SUCCEED WITH H: 155, PLAIN: 163
# -------------------------------------------------------------------------------
# 28 map
# BOTH SUCCEED WITH H: 191, PLAIN: 294
# -------------------------------------------------------------------------------
# 29 map
# BOTH SUCCEED WITH H: 54, PLAIN: 52
# -------------------------------------------------------------------------------
# 30 map
# BOTH SUCCEED WITH H: 217, PLAIN: 263
# -------------------------------------------------------------------------------
# 31 map
# BOTH SUCCEED WITH H: 3152, PLAIN: 3677
# -------------------------------------------------------------------------------
# 32 map
# BOTH SUCCEED WITH H: 39, PLAIN: 68
# -------------------------------------------------------------------------------
# 33 map
# BOTH SUCCEED WITH H: 311, PLAIN: 470
# -------------------------------------------------------------------------------
# 34 map
# BOTH SUCCEED WITH H: 1431, PLAIN: 1835
# -------------------------------------------------------------------------------
# 35 map
# BOTH SUCCEED WITH H: 530, PLAIN: 533
# -------------------------------------------------------------------------------
# 36 map
# BOTH SUCCEED WITH H: 99, PLAIN: 71
# -------------------------------------------------------------------------------
# 38 map
# BOTH SUCCEED WITH H: 157, PLAIN: 167
# -------------------------------------------------------------------------------
# 39 map
# BOTH SUCCEED WITH H: 20, PLAIN: 21
# -------------------------------------------------------------------------------
# 40 map
# BOTH SUCCEED WITH H: 15, PLAIN: 26
# -------------------------------------------------------------------------------
# 41 map
# BOTH SUCCEED WITH H: 98, PLAIN: 98
# -------------------------------------------------------------------------------
# 42 map
# BOTH SUCCEED WITH H: 55, PLAIN: 66
# -------------------------------------------------------------------------------
# 43 map
# BOTH SUCCEED WITH H: 9, PLAIN: 15
# -------------------------------------------------------------------------------
# 44 map
# BOTH SUCCEED WITH H: 192, PLAIN: 256
# -------------------------------------------------------------------------------
# 45 map
# BOTH SUCCEED WITH H: 128, PLAIN: 254
# -------------------------------------------------------------------------------
# 46 map
# BOTH SUCCEED WITH H: 23, PLAIN: 36
# -------------------------------------------------------------------------------
# 47 map
# BOTH SUCCEED WITH H: 57, PLAIN: 38
# -------------------------------------------------------------------------------
# 48 map
# BOTH SUCCEED WITH H: 90, PLAIN: 107
# -------------------------------------------------------------------------------
# 49 map
# BOTH SUCCEED WITH H: 1266, PLAIN: 2137
# -------------------------------------------------------------------------------
# 50 map
# BOTH SUCCEED WITH H: 191, PLAIN: 196
# -------------------------------------------------------------------------------

# %%
mcts.success_traj
# Out:
# {1: set(),
#  2: {((2, 1, 1), (2, 1, 0), (2, 0, 0)), ((2, 2, 0), (2, 1, 0), (2, 0, 0))}}

# %%
mcts.root.traj_dict
# Out:
# {2: [], 1: [(1, 7)]}

# %%
failed_cases = [20, 32, 36, 43, 51, 52, 58, 64, 66, 67]  # at 1 / sqrt(2)
explorationConstant = 10 / math.sqrt(2)
iter_Limit = 40000

for random_seed in failed_cases:
    H_level = 2
    mcts = H_MCTS(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
    mcts.Env.plot_grid(1)
    H_traj, H_reward = mcts.search()
    print(f'{random_seed} with {H_traj} H-MCTS')
    total_H.append(H_reward)

    H_level = 1
    mcts = H_MCTS(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
    plain_traj, plain_reward = mcts.search()
    print(f'{random_seed} with {plain_traj} plain-MCTS')
    total_plain.append(plain_reward)
    print('-----------------------------------------------------------------------------------------')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Generate two random DataFrames with 50 rows and 10000 columns
df1 = pd.DataFrame(total_H)
df2 = pd.DataFrame(total_plain)

# Calculate the average separately for each column
average_df1 = df1.mean(axis=0)
average_df2 = df2.mean(axis=0)

# Calculate the standard deviation separately for each column
std_dev_df1 = df1.std(axis=0)
std_dev_df2 = df2.std(axis=0)

# Plot the averages as line charts
plt.plot(range(10000), average_df1, label='H-MCTS')
plt.plot(range(10000), average_df2, label='Plain-MCTS')

# Show the deviation as shaded regions
plt.fill_between(range(10000), average_df1 - std_dev_df1, average_df1 + std_dev_df1, alpha=0.3)
plt.fill_between(range(10000), average_df2 - std_dev_df2, average_df2 + std_dev_df2, alpha=0.3)

plt.xlabel('Iterations')
plt.ylabel('Average Sum of reward')
plt.title('H-MCTS   VS   Plain-MCTS')
plt.legend()
plt.show()
