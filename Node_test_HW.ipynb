# %% [markdown]
# ### H_tree check

# %%
from src.Planners.H_MCTS_HW import H_MCTS_HW

import math
import pandas as pd

# %%
l1_rows = 10
l1_cols = 10
l1_width = 2
l1_height = 2
# H_level = 2
num_barrier = 16
random_seed= 25

explorationConstant = 1 / math.sqrt(2)
grid_setting = (l1_rows, l1_cols, l1_width, l1_height)

iter_Limit = 5000
H_level = 2

# %%
H_mcts = H_MCTS_HW(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)

# %%
r = 0
dead_list = [37, 59, 62]  # unfeasible set

total_H = []
total_plain = []

for random_seed in range(0, 51):
    if random_seed in dead_list:
        continue
    else:
        print(f'{random_seed+1} map')
        
        H_level = 2
        H_mcts = H_MCTS_HW(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
        H_mcts.env.plot_grid(1)
        H_traj, H_success, H_iter = H_mcts.search()
        
        H_level = 1
        Plain_mcts = H_MCTS_HW(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
        Plain_traj, Plain_success, Plain_iter = Plain_mcts.search()

        #print(f'{random_seed} with {H_traj} H-MCTS')
        # print(mcts.success_traj[2])
        
        if H_success and not Plain_success:
            print('ONLY H-MCTS SUCCEED')
            print(H_traj, H_iter)
            
        elif H_success and Plain_success:
            print(f"BOTH SUCCEED WITH H: {H_iter}, PLAIN: {Plain_iter}")
        
        elif not H_success and Plain_success:
            print('ONLY PLAIN-MCTS SUCCEED')
            print(Plain_traj, Plain_iter)
        
        else:
            print('BOTH FAILED')
        print('-------------------------------------------------------------------------------')
# Out:
# 1 map
# BOTH FAILED
# -------------------------------------------------------------------------------
# 2 map
# ONLY H-MCTS SUCCEED
# [(1, 4, 3), (1, 4, 4), (1, 4, 5), (1, 4, 6), (1, 3, 6), (1, 3, 7), (1, 2, 7), (1, 2, 8), (1, 2, 9), (1, 1, 9), (1, 0, 9)] 4450
# -------------------------------------------------------------------------------
# 3 map
# BOTH SUCCEED WITH H: 453, PLAIN: 426
# -------------------------------------------------------------------------------
# 4 map
# BOTH SUCCEED WITH H: 2121, PLAIN: 3709
# -------------------------------------------------------------------------------
# 5 map
# BOTH SUCCEED WITH H: 491, PLAIN: 540
# -------------------------------------------------------------------------------
# 6 map
# BOTH SUCCEED WITH H: 97, PLAIN: 178
# -------------------------------------------------------------------------------
# 7 map
# BOTH SUCCEED WITH H: 97, PLAIN: 140
# -------------------------------------------------------------------------------
# 8 map
# BOTH SUCCEED WITH H: 168, PLAIN: 165
# -------------------------------------------------------------------------------
# 9 map
# BOTH SUCCEED WITH H: 38, PLAIN: 67
# -------------------------------------------------------------------------------
# 10 map
# BOTH SUCCEED WITH H: 327, PLAIN: 435
# -------------------------------------------------------------------------------
# 11 map
# BOTH SUCCEED WITH H: 192, PLAIN: 178
# -------------------------------------------------------------------------------
# 12 map
# ONLY H-MCTS SUCCEED
# [(1, 8, 8), (1, 7, 8), (1, 6, 8), (1, 5, 8), (1, 4, 8), (1, 4, 7), (1, 3, 7), (1, 2, 7), (1, 1, 7), (1, 0, 7), (1, 0, 6), (1, 0, 5)] 4348
# -------------------------------------------------------------------------------
# 13 map
# BOTH SUCCEED WITH H: 2549, PLAIN: 2852
# -------------------------------------------------------------------------------
# 14 map
# BOTH SUCCEED WITH H: 2920, PLAIN: 4897
# -------------------------------------------------------------------------------
# 15 map
# ONLY H-MCTS SUCCEED
# [(1, 3, 9), (1, 3, 8), (1, 3, 7), (1, 3, 6), (1, 3, 5), (1, 2, 5), (1, 2, 4), (1, 2, 3), (1, 2, 2), (1, 1, 2), (1, 1, 1)] 4135
# -------------------------------------------------------------------------------
# 16 map
# BOTH SUCCEED WITH H: 532, PLAIN: 728
# -------------------------------------------------------------------------------
# 17 map
# BOTH SUCCEED WITH H: 638, PLAIN: 761
# -------------------------------------------------------------------------------
# 18 map
# BOTH SUCCEED WITH H: 704, PLAIN: 736
# -------------------------------------------------------------------------------
# 19 map
# BOTH SUCCEED WITH H: 332, PLAIN: 739
# -------------------------------------------------------------------------------
# 20 map
# BOTH SUCCEED WITH H: 465, PLAIN: 536
# -------------------------------------------------------------------------------
# 21 map
# BOTH SUCCEED WITH H: 313, PLAIN: 394
# -------------------------------------------------------------------------------
# 22 map
# BOTH SUCCEED WITH H: 63, PLAIN: 148
# -------------------------------------------------------------------------------
# 23 map
# BOTH FAILED
# -------------------------------------------------------------------------------
# 24 map
# BOTH SUCCEED WITH H: 1436, PLAIN: 1672
# -------------------------------------------------------------------------------
# 25 map
# BOTH SUCCEED WITH H: 1327, PLAIN: 1681
# -------------------------------------------------------------------------------
# 26 map
# BOTH SUCCEED WITH H: 373, PLAIN: 498
# -------------------------------------------------------------------------------
# 27 map
# BOTH FAILED
# -------------------------------------------------------------------------------
# 28 map
# BOTH SUCCEED WITH H: 12, PLAIN: 23
# -------------------------------------------------------------------------------
# 29 map
# BOTH FAILED
# -------------------------------------------------------------------------------
# 30 map
# BOTH SUCCEED WITH H: 700, PLAIN: 865
# -------------------------------------------------------------------------------
# 31 map
# BOTH SUCCEED WITH H: 117, PLAIN: 80
# -------------------------------------------------------------------------------
# 32 map
# BOTH SUCCEED WITH H: 3037, PLAIN: 3436
# -------------------------------------------------------------------------------
# 33 map
# BOTH FAILED
# -------------------------------------------------------------------------------
# 34 map
# BOTH SUCCEED WITH H: 3822, PLAIN: 4472
# -------------------------------------------------------------------------------
# 35 map
# BOTH SUCCEED WITH H: 632, PLAIN: 986
# -------------------------------------------------------------------------------
# 36 map
# BOTH SUCCEED WITH H: 24, PLAIN: 46
# -------------------------------------------------------------------------------
# 37 map
# BOTH FAILED
# -------------------------------------------------------------------------------
# 39 map
# BOTH SUCCEED WITH H: 156, PLAIN: 290
# -------------------------------------------------------------------------------
# 40 map
# BOTH SUCCEED WITH H: 989, PLAIN: 1017
# -------------------------------------------------------------------------------
# 41 map
# BOTH SUCCEED WITH H: 1131, PLAIN: 1820
# -------------------------------------------------------------------------------
# 42 map
# BOTH SUCCEED WITH H: 12, PLAIN: 17
# -------------------------------------------------------------------------------
# 43 map
# BOTH SUCCEED WITH H: 1579, PLAIN: 3170
# -------------------------------------------------------------------------------
# 44 map
# BOTH SUCCEED WITH H: 367, PLAIN: 436
# -------------------------------------------------------------------------------
# 45 map
# BOTH FAILED
# -------------------------------------------------------------------------------
# 46 map
# BOTH SUCCEED WITH H: 659, PLAIN: 1005
# -------------------------------------------------------------------------------
# 47 map
# BOTH SUCCEED WITH H: 1547, PLAIN: 1779
# -------------------------------------------------------------------------------
# 48 map
# BOTH SUCCEED WITH H: 558, PLAIN: 389
# -------------------------------------------------------------------------------
# 49 map
# BOTH SUCCEED WITH H: 67, PLAIN: 81
# -------------------------------------------------------------------------------
# 50 map
# BOTH SUCCEED WITH H: 407, PLAIN: 521
# -------------------------------------------------------------------------------
# 51 map
# BOTH SUCCEED WITH H: 124, PLAIN: 152
# -------------------------------------------------------------------------------

# %%
mcts.success_traj
# Out:
# {1: set(),
#  2: {((2, 1, 1), (2, 1, 0), (2, 0, 0)), ((2, 2, 0), (2, 1, 0), (2, 0, 0))}}

# %%
mcts.root.traj_dict
# Out:
# {2: [], 1: [(1, 7)]}

# %%
failed_cases = [20, 32, 36, 43, 51, 52, 58, 64, 66, 67]  # at 1 / sqrt(2)
explorationConstant = 10 / math.sqrt(2)
iter_Limit = 40000

for random_seed in failed_cases:
    H_level = 2
    mcts = H_MCTS(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
    mcts.Env.plot_grid(1)
    H_traj, H_reward = mcts.search()
    print(f'{random_seed} with {H_traj} H-MCTS')
    total_H.append(H_reward)

    H_level = 1
    mcts = H_MCTS(grid_setting, iter_Limit=iter_Limit, H_level=H_level, explorationConstant=explorationConstant, num_barrier=num_barrier, random_seed=random_seed)
    plain_traj, plain_reward = mcts.search()
    print(f'{random_seed} with {plain_traj} plain-MCTS')
    total_plain.append(plain_reward)
    print('-----------------------------------------------------------------------------------------')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Generate two random DataFrames with 50 rows and 10000 columns
df1 = pd.DataFrame(total_H)
df2 = pd.DataFrame(total_plain)

# Calculate the average separately for each column
average_df1 = df1.mean(axis=0)
average_df2 = df2.mean(axis=0)

# Calculate the standard deviation separately for each column
std_dev_df1 = df1.std(axis=0)
std_dev_df2 = df2.std(axis=0)

# Plot the averages as line charts
plt.plot(range(10000), average_df1, label='H-MCTS')
plt.plot(range(10000), average_df2, label='Plain-MCTS')

# Show the deviation as shaded regions
plt.fill_between(range(10000), average_df1 - std_dev_df1, average_df1 + std_dev_df1, alpha=0.3)
plt.fill_between(range(10000), average_df2 - std_dev_df2, average_df2 + std_dev_df2, alpha=0.3)

plt.xlabel('Iterations')
plt.ylabel('Average Sum of reward')
plt.title('H-MCTS   VS   Plain-MCTS')
plt.legend()
plt.show()
